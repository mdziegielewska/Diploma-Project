# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.7 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/train_test_data"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'seresnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
# model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=10)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=16,
        epochs=100,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/seresnet34_imagenet_1000_no_top.h5
# 86315168/86315168 [==============================] - 2s 0us/step
# Epoch 1/100
# 90/90 [==============================] - 49s 344ms/step - loss: 0.9680 - iou_score: 0.0266 - f1-score: 0.5871 - precision: 0.7254 - recall: 0.5819 - val_loss: 0.9681 - val_iou_score: 0.0265 - val_f1-score: 0.4438 - val_precision: 0.7066 - val_recall: 0.5506 - lr: 0.0010
# Epoch 2/100
# 90/90 [==============================] - 27s 300ms/step - loss: 0.8589 - iou_score: 0.1039 - f1-score: 0.7777 - precision: 0.8054 - recall: 0.7632 - val_loss: 0.8668 - val_iou_score: 0.1021 - val_f1-score: 0.5838 - val_precision: 0.8417 - val_recall: 0.5269 - lr: 0.0010
# Epoch 3/100
# 90/90 [==============================] - 27s 304ms/step - loss: 0.8403 - iou_score: 0.1215 - f1-score: 0.8348 - precision: 0.8537 - recall: 0.8232 - val_loss: 0.8515 - val_iou_score: 0.1151 - val_f1-score: 0.7228 - val_precision: 0.8358 - val_recall: 0.6830 - lr: 0.0010
# Epoch 4/100
# 90/90 [==============================] - 28s 308ms/step - loss: 0.8314 - iou_score: 0.1306 - f1-score: 0.8549 - precision: 0.8717 - recall: 0.8429 - val_loss: 0.8373 - val_iou_score: 0.1252 - val_f1-score: 0.8090 - val_precision: 0.8852 - val_recall: 0.7647 - lr: 0.0010
# Epoch 5/100
# 90/90 [==============================] - 28s 310ms/step - loss: 0.8276 - iou_score: 0.1343 - f1-score: 0.8645 - precision: 0.8796 - recall: 0.8534 - val_loss: 0.8320 - val_iou_score: 0.1309 - val_f1-score: 0.8294 - val_precision: 0.8975 - val_recall: 0.7802 - lr: 0.0010
# Epoch 6/100
# 90/90 [==============================] - 28s 313ms/step - loss: 0.8237 - iou_score: 0.1387 - f1-score: 0.8712 - precision: 0.8870 - recall: 0.8594 - val_loss: 0.8291 - val_iou_score: 0.1325 - val_f1-score: 0.8523 - val_precision: 0.8943 - val_recall: 0.8233 - lr: 0.0010
# Epoch 7/100
# 90/90 [==============================] - 28s 315ms/step - loss: 0.8204 - iou_score: 0.1426 - f1-score: 0.8764 - precision: 0.8921 - recall: 0.8649 - val_loss: 0.8249 - val_iou_score: 0.1371 - val_f1-score: 0.8683 - val_precision: 0.9017 - val_recall: 0.8414 - lr: 0.0010
# Epoch 8/100
# 90/90 [==============================] - 28s 315ms/step - loss: 0.8181 - iou_score: 0.1453 - f1-score: 0.8813 - precision: 0.8974 - recall: 0.8693 - val_loss: 0.8265 - val_iou_score: 0.1348 - val_f1-score: 0.8677 - val_precision: 0.8858 - val_recall: 0.8537 - lr: 0.0010
# Epoch 9/100
# 90/90 [==============================] - 28s 317ms/step - loss: 0.8164 - iou_score: 0.1471 - f1-score: 0.8848 - precision: 0.9013 - recall: 0.8720 - val_loss: 0.8256 - val_iou_score: 0.1369 - val_f1-score: 0.8632 - val_precision: 0.8765 - val_recall: 0.8536 - lr: 0.0010
# Epoch 10/100
# 90/90 [==============================] - 29s 318ms/step - loss: 0.8159 - iou_score: 0.1481 - f1-score: 0.8811 - precision: 0.8975 - recall: 0.8693 - val_loss: 0.8260 - val_iou_score: 0.1368 - val_f1-score: 0.8545 - val_precision: 0.8952 - val_recall: 0.8228 - lr: 0.0010
# Epoch 11/100
# 90/90 [==============================] - 29s 319ms/step - loss: 0.8104 - iou_score: 0.1546 - f1-score: 0.8894 - precision: 0.9012 - recall: 0.8803 - val_loss: 0.8215 - val_iou_score: 0.1413 - val_f1-score: 0.8673 - val_precision: 0.8823 - val_recall: 0.8568 - lr: 0.0010
# Epoch 12/100
# 90/90 [==============================] - 29s 320ms/step - loss: 0.8082 - iou_score: 0.1573 - f1-score: 0.8925 - precision: 0.9045 - recall: 0.8833 - val_loss: 0.8169 - val_iou_score: 0.1472 - val_f1-score: 0.8692 - val_precision: 0.9148 - val_recall: 0.8340 - lr: 0.0010
# Epoch 13/100
# 90/90 [==============================] - 29s 320ms/step - loss: 0.8058 - iou_score: 0.1604 - f1-score: 0.8963 - precision: 0.9081 - recall: 0.8873 - val_loss: 0.8174 - val_iou_score: 0.1456 - val_f1-score: 0.8857 - val_precision: 0.9065 - val_recall: 0.8690 - lr: 0.0010
# Epoch 14/100
# 90/90 [==============================] - 29s 321ms/step - loss: 0.8026 - iou_score: 0.1643 - f1-score: 0.9012 - precision: 0.9124 - recall: 0.8924 - val_loss: 0.8155 - val_iou_score: 0.1478 - val_f1-score: 0.8867 - val_precision: 0.8895 - val_recall: 0.8850 - lr: 0.0010
# Epoch 15/100
# 90/90 [==============================] - 29s 323ms/step - loss: 0.8004 - iou_score: 0.1672 - f1-score: 0.9038 - precision: 0.9152 - recall: 0.8948 - val_loss: 0.8148 - val_iou_score: 0.1484 - val_f1-score: 0.8886 - val_precision: 0.8896 - val_recall: 0.8888 - lr: 0.0010
# Epoch 16/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7997 - iou_score: 0.1681 - f1-score: 0.9039 - precision: 0.9161 - recall: 0.8946 - val_loss: 0.8185 - val_iou_score: 0.1442 - val_f1-score: 0.8847 - val_precision: 0.9101 - val_recall: 0.8650 - lr: 0.0010
# Epoch 17/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7993 - iou_score: 0.1687 - f1-score: 0.9060 - precision: 0.9161 - recall: 0.8982 - val_loss: 0.8161 - val_iou_score: 0.1472 - val_f1-score: 0.8864 - val_precision: 0.9063 - val_recall: 0.8697 - lr: 0.0010
# Epoch 18/100
# 90/90 [==============================] - 29s 323ms/step - loss: 0.7970 - iou_score: 0.1718 - f1-score: 0.9093 - precision: 0.9206 - recall: 0.9002 - val_loss: 0.8148 - val_iou_score: 0.1489 - val_f1-score: 0.8865 - val_precision: 0.9089 - val_recall: 0.8675 - lr: 0.0010
# Epoch 19/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7975 - iou_score: 0.1712 - f1-score: 0.9080 - precision: 0.9183 - recall: 0.8996 - val_loss: 0.8127 - val_iou_score: 0.1514 - val_f1-score: 0.8904 - val_precision: 0.9134 - val_recall: 0.8702 - lr: 0.0010
# Epoch 20/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7952 - iou_score: 0.1741 - f1-score: 0.9123 - precision: 0.9221 - recall: 0.9043 - val_loss: 0.8138 - val_iou_score: 0.1498 - val_f1-score: 0.8843 - val_precision: 0.8828 - val_recall: 0.8923 - lr: 0.0010
# Epoch 21/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7949 - iou_score: 0.1746 - f1-score: 0.9128 - precision: 0.9233 - recall: 0.9043 - val_loss: 0.8127 - val_iou_score: 0.1512 - val_f1-score: 0.8872 - val_precision: 0.9254 - val_recall: 0.8568 - lr: 0.0010
# Epoch 22/100
# 90/90 [==============================] - 29s 321ms/step - loss: 0.7939 - iou_score: 0.1759 - f1-score: 0.9143 - precision: 0.9245 - recall: 0.9062 - val_loss: 0.8098 - val_iou_score: 0.1548 - val_f1-score: 0.8931 - val_precision: 0.9253 - val_recall: 0.8661 - lr: 0.0010
# Epoch 23/100
# 90/90 [==============================] - 29s 321ms/step - loss: 0.7936 - iou_score: 0.1764 - f1-score: 0.9140 - precision: 0.9247 - recall: 0.9052 - val_loss: 0.8117 - val_iou_score: 0.1529 - val_f1-score: 0.8852 - val_precision: 0.9258 - val_recall: 0.8525 - lr: 0.0010
# Epoch 24/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7925 - iou_score: 0.1780 - f1-score: 0.9151 - precision: 0.9246 - recall: 0.9078 - val_loss: 0.8110 - val_iou_score: 0.1534 - val_f1-score: 0.8951 - val_precision: 0.9036 - val_recall: 0.8889 - lr: 0.0010
# Epoch 25/100
# 90/90 [==============================] - 29s 321ms/step - loss: 0.7908 - iou_score: 0.1801 - f1-score: 0.9186 - precision: 0.9277 - recall: 0.9111 - val_loss: 0.8103 - val_iou_score: 0.1541 - val_f1-score: 0.8961 - val_precision: 0.9177 - val_recall: 0.8780 - lr: 0.0010
# Epoch 26/100
# 90/90 [==============================] - 29s 321ms/step - loss: 0.7906 - iou_score: 0.1807 - f1-score: 0.9191 - precision: 0.9286 - recall: 0.9113 - val_loss: 0.8101 - val_iou_score: 0.1542 - val_f1-score: 0.8978 - val_precision: 0.9163 - val_recall: 0.8816 - lr: 0.0010
# Epoch 27/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7902 - iou_score: 0.1811 - f1-score: 0.9192 - precision: 0.9286 - recall: 0.9114 - val_loss: 0.8091 - val_iou_score: 0.1555 - val_f1-score: 0.8979 - val_precision: 0.9048 - val_recall: 0.8922 - lr: 0.0010
# Epoch 28/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7890 - iou_score: 0.1830 - f1-score: 0.9214 - precision: 0.9314 - recall: 0.9132 - val_loss: 0.8085 - val_iou_score: 0.1562 - val_f1-score: 0.8976 - val_precision: 0.9091 - val_recall: 0.8881 - lr: 0.0010
# Epoch 29/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7884 - iou_score: 0.1838 - f1-score: 0.9216 - precision: 0.9310 - recall: 0.9138 - val_loss: 0.8089 - val_iou_score: 0.1559 - val_f1-score: 0.8998 - val_precision: 0.9122 - val_recall: 0.8903 - lr: 0.0010
# Epoch 30/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7881 - iou_score: 0.1843 - f1-score: 0.9225 - precision: 0.9317 - recall: 0.9150 - val_loss: 0.8092 - val_iou_score: 0.1553 - val_f1-score: 0.8995 - val_precision: 0.9024 - val_recall: 0.8981 - lr: 0.0010
# Epoch 31/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7878 - iou_score: 0.1845 - f1-score: 0.9232 - precision: 0.9328 - recall: 0.9153 - val_loss: 0.8089 - val_iou_score: 0.1558 - val_f1-score: 0.8976 - val_precision: 0.9024 - val_recall: 0.8955 - lr: 0.0010
# Epoch 32/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7870 - iou_score: 0.1857 - f1-score: 0.9241 - precision: 0.9331 - recall: 0.9164 - val_loss: 0.8107 - val_iou_score: 0.1534 - val_f1-score: 0.8968 - val_precision: 0.9084 - val_recall: 0.8882 - lr: 0.0010
# Epoch 33/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7872 - iou_score: 0.1856 - f1-score: 0.9224 - precision: 0.9318 - recall: 0.9146 - val_loss: 0.8127 - val_iou_score: 0.1518 - val_f1-score: 0.8859 - val_precision: 0.8897 - val_recall: 0.8839 - lr: 0.0010
# Epoch 34/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7865 - iou_score: 0.1864 - f1-score: 0.9237 - precision: 0.9320 - recall: 0.9168 - val_loss: 0.8118 - val_iou_score: 0.1518 - val_f1-score: 0.8958 - val_precision: 0.9172 - val_recall: 0.8801 - lr: 0.0010
# Epoch 35/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7852 - iou_score: 0.1885 - f1-score: 0.9261 - precision: 0.9352 - recall: 0.9182 - val_loss: 0.8117 - val_iou_score: 0.1527 - val_f1-score: 0.8928 - val_precision: 0.9084 - val_recall: 0.8802 - lr: 0.0010
# Epoch 36/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7846 - iou_score: 0.1893 - f1-score: 0.9267 - precision: 0.9351 - recall: 0.9195 - val_loss: 0.8105 - val_iou_score: 0.1537 - val_f1-score: 0.8980 - val_precision: 0.9240 - val_recall: 0.8764 - lr: 0.0010
# Epoch 37/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7845 - iou_score: 0.1893 - f1-score: 0.9273 - precision: 0.9358 - recall: 0.9201 - val_loss: 0.8094 - val_iou_score: 0.1551 - val_f1-score: 0.8989 - val_precision: 0.9149 - val_recall: 0.8847 - lr: 0.0010
# Epoch 38/100
# 90/90 [==============================] - 29s 322ms/step - loss: 0.7840 - iou_score: 0.1901 - f1-score: 0.9275 - precision: 0.9357 - recall: 0.9206 - val_loss: 0.8106 - val_iou_score: 0.1540 - val_f1-score: 0.8948 - val_precision: 0.9156 - val_recall: 0.8774 - lr: 0.0010

# %%
model_in_mem.save('psp_softmax_1500_seresnet34.hdf5')
from google.colab import files
files.download('psp_softmax_1500_seresnet34.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
# model = load_model('/content/psp_softmax_1500_vgg16.hdf5', compile=False)
model = model_in_mem

# IoU
X_test = preprocess_input(X_test)
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 4s 116ms/step
# Mean IoU = 0.8285878
# [[1.6040425e+07 4.5118000e+04 2.3217400e+05 5.1000000e+01]
#  [3.4689000e+04 4.5760400e+05 2.9139000e+04 2.1870000e+03]
#  [9.7862000e+04 9.4890000e+03 6.6299920e+06 4.1200000e+02]
#  [8.1500000e+02 1.7570000e+03 1.3120000e+03 9.9340000e+03]]
# IoU for class1 is:  0.9750346
# IoU for class2 is:  0.78899556
# IoU for class3 is:  0.9470903
# IoU for class4 is:  0.60323054

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, vmin=0, vmax=3, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
