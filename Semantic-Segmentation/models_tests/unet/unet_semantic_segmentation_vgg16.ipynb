# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.2 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/train_test_data"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'vgg16'
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
# model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=10)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=8,
        epochs=100,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/100
# 180/180 [==============================] - 98s 422ms/step - loss: 0.9705 - iou_score: 0.0259 - f1-score: 0.5337 - precision: 0.6939 - recall: 0.5271 - val_loss: 0.9603 - val_iou_score: 0.0307 - val_f1-score: 0.4862 - val_precision: 0.8440 - val_recall: 0.4800 - lr: 0.0010
# Epoch 2/100
# 180/180 [==============================] - 70s 388ms/step - loss: 0.9061 - iou_score: 0.0680 - f1-score: 0.6316 - precision: 0.7241 - recall: 0.6170 - val_loss: 0.8848 - val_iou_score: 0.0861 - val_f1-score: 0.5951 - val_precision: 0.7821 - val_recall: 0.5504 - lr: 0.0010
# Epoch 3/100
# 180/180 [==============================] - 71s 396ms/step - loss: 0.8786 - iou_score: 0.0881 - f1-score: 0.7359 - precision: 0.7790 - recall: 0.7162 - val_loss: 0.8778 - val_iou_score: 0.0917 - val_f1-score: 0.7178 - val_precision: 0.7571 - val_recall: 0.7173 - lr: 0.0010
# Epoch 4/100
# 180/180 [==============================] - 72s 399ms/step - loss: 0.8679 - iou_score: 0.0964 - f1-score: 0.7736 - precision: 0.8095 - recall: 0.7550 - val_loss: 0.8651 - val_iou_score: 0.0994 - val_f1-score: 0.7648 - val_precision: 0.7878 - val_recall: 0.7636 - lr: 0.0010
# Epoch 5/100
# 180/180 [==============================] - 72s 399ms/step - loss: 0.8693 - iou_score: 0.0956 - f1-score: 0.7666 - precision: 0.8038 - recall: 0.7499 - val_loss: 0.8745 - val_iou_score: 0.0945 - val_f1-score: 0.7199 - val_precision: 0.8454 - val_recall: 0.6560 - lr: 0.0010
# Epoch 6/100
# 180/180 [==============================] - 72s 402ms/step - loss: 0.8596 - iou_score: 0.1037 - f1-score: 0.7877 - precision: 0.8205 - recall: 0.7728 - val_loss: 0.8688 - val_iou_score: 0.1088 - val_f1-score: 0.6282 - val_precision: 0.8097 - val_recall: 0.6125 - lr: 0.0010
# Epoch 7/100
# 180/180 [==============================] - 73s 403ms/step - loss: 0.8556 - iou_score: 0.1081 - f1-score: 0.7982 - precision: 0.8275 - recall: 0.7837 - val_loss: 0.8621 - val_iou_score: 0.1055 - val_f1-score: 0.7217 - val_precision: 0.7156 - val_recall: 0.8032 - lr: 0.0010
# Epoch 8/100
# 180/180 [==============================] - 73s 404ms/step - loss: 0.8562 - iou_score: 0.1072 - f1-score: 0.8012 - precision: 0.8341 - recall: 0.7846 - val_loss: 0.8507 - val_iou_score: 0.1106 - val_f1-score: 0.8187 - val_precision: 0.8325 - val_recall: 0.8114 - lr: 0.0010
# Epoch 9/100
# 180/180 [==============================] - 73s 404ms/step - loss: 0.8486 - iou_score: 0.1138 - f1-score: 0.8159 - precision: 0.8410 - recall: 0.8013 - val_loss: 0.8535 - val_iou_score: 0.1115 - val_f1-score: 0.8035 - val_precision: 0.8167 - val_recall: 0.8041 - lr: 0.0010
# Epoch 10/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8463 - iou_score: 0.1164 - f1-score: 0.8196 - precision: 0.8477 - recall: 0.8040 - val_loss: 0.8496 - val_iou_score: 0.1131 - val_f1-score: 0.7864 - val_precision: 0.8630 - val_recall: 0.7396 - lr: 0.0010
# Epoch 11/100
# 180/180 [==============================] - 75s 419ms/step - loss: 0.8414 - iou_score: 0.1208 - f1-score: 0.8319 - precision: 0.8547 - recall: 0.8185 - val_loss: 0.8456 - val_iou_score: 0.1156 - val_f1-score: 0.8333 - val_precision: 0.8774 - val_recall: 0.8049 - lr: 0.0010
# Epoch 12/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8403 - iou_score: 0.1224 - f1-score: 0.8323 - precision: 0.8572 - recall: 0.8175 - val_loss: 0.8407 - val_iou_score: 0.1207 - val_f1-score: 0.8340 - val_precision: 0.8256 - val_recall: 0.8484 - lr: 0.0010
# Epoch 13/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8359 - iou_score: 0.1262 - f1-score: 0.8443 - precision: 0.8647 - recall: 0.8314 - val_loss: 0.8455 - val_iou_score: 0.1165 - val_f1-score: 0.8256 - val_precision: 0.8500 - val_recall: 0.8200 - lr: 0.0010
# Epoch 14/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8351 - iou_score: 0.1271 - f1-score: 0.8460 - precision: 0.8699 - recall: 0.8309 - val_loss: 0.8407 - val_iou_score: 0.1202 - val_f1-score: 0.8445 - val_precision: 0.8890 - val_recall: 0.8125 - lr: 0.0010
# Epoch 15/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8353 - iou_score: 0.1270 - f1-score: 0.8463 - precision: 0.8670 - recall: 0.8334 - val_loss: 0.8443 - val_iou_score: 0.1165 - val_f1-score: 0.8412 - val_precision: 0.8702 - val_recall: 0.8309 - lr: 0.0010
# Epoch 16/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8332 - iou_score: 0.1291 - f1-score: 0.8522 - precision: 0.8739 - recall: 0.8385 - val_loss: 0.8367 - val_iou_score: 0.1251 - val_f1-score: 0.8409 - val_precision: 0.8561 - val_recall: 0.8367 - lr: 0.0010
# Epoch 17/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8295 - iou_score: 0.1327 - f1-score: 0.8591 - precision: 0.8803 - recall: 0.8454 - val_loss: 0.8365 - val_iou_score: 0.1246 - val_f1-score: 0.8505 - val_precision: 0.8871 - val_recall: 0.8241 - lr: 0.0010
# Epoch 18/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8334 - iou_score: 0.1294 - f1-score: 0.8492 - precision: 0.8702 - recall: 0.8360 - val_loss: 0.8418 - val_iou_score: 0.1204 - val_f1-score: 0.8231 - val_precision: 0.8757 - val_recall: 0.7866 - lr: 0.0010
# Epoch 19/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8301 - iou_score: 0.1323 - f1-score: 0.8566 - precision: 0.8786 - recall: 0.8427 - val_loss: 0.8405 - val_iou_score: 0.1231 - val_f1-score: 0.8118 - val_precision: 0.8216 - val_recall: 0.8235 - lr: 0.0010
# Epoch 20/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8473 - iou_score: 0.1159 - f1-score: 0.8186 - precision: 0.8480 - recall: 0.8013 - val_loss: 0.8404 - val_iou_score: 0.1206 - val_f1-score: 0.8474 - val_precision: 0.8864 - val_recall: 0.8201 - lr: 0.0010
# Epoch 21/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8331 - iou_score: 0.1297 - f1-score: 0.8510 - precision: 0.8739 - recall: 0.8358 - val_loss: 0.8454 - val_iou_score: 0.1164 - val_f1-score: 0.8338 - val_precision: 0.8769 - val_recall: 0.8128 - lr: 0.0010
# Epoch 22/100
# 180/180 [==============================] - 74s 411ms/step - loss: 0.8292 - iou_score: 0.1335 - f1-score: 0.8590 - precision: 0.8807 - recall: 0.8446 - val_loss: 0.8380 - val_iou_score: 0.1228 - val_f1-score: 0.8555 - val_precision: 0.8789 - val_recall: 0.8412 - lr: 0.0010
# Epoch 23/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8261 - iou_score: 0.1367 - f1-score: 0.8651 - precision: 0.8870 - recall: 0.8502 - val_loss: 0.8346 - val_iou_score: 0.1265 - val_f1-score: 0.8526 - val_precision: 0.8698 - val_recall: 0.8425 - lr: 0.0010
# Epoch 24/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8262 - iou_score: 0.1365 - f1-score: 0.8664 - precision: 0.8890 - recall: 0.8509 - val_loss: 0.8342 - val_iou_score: 0.1270 - val_f1-score: 0.8609 - val_precision: 0.8756 - val_recall: 0.8505 - lr: 0.0010
# Epoch 25/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8275 - iou_score: 0.1356 - f1-score: 0.8624 - precision: 0.8830 - recall: 0.8486 - val_loss: 0.8375 - val_iou_score: 0.1239 - val_f1-score: 0.8508 - val_precision: 0.8624 - val_recall: 0.8474 - lr: 0.0010
# Epoch 26/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8248 - iou_score: 0.1382 - f1-score: 0.8684 - precision: 0.8897 - recall: 0.8540 - val_loss: 0.8352 - val_iou_score: 0.1255 - val_f1-score: 0.8596 - val_precision: 0.8928 - val_recall: 0.8373 - lr: 0.0010
# Epoch 27/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8231 - iou_score: 0.1398 - f1-score: 0.8729 - precision: 0.8941 - recall: 0.8591 - val_loss: 0.8329 - val_iou_score: 0.1282 - val_f1-score: 0.8635 - val_precision: 0.8800 - val_recall: 0.8559 - lr: 0.0010
# Epoch 28/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8228 - iou_score: 0.1400 - f1-score: 0.8729 - precision: 0.8933 - recall: 0.8597 - val_loss: 0.8328 - val_iou_score: 0.1281 - val_f1-score: 0.8637 - val_precision: 0.8800 - val_recall: 0.8535 - lr: 0.0010
# Epoch 29/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8225 - iou_score: 0.1405 - f1-score: 0.8735 - precision: 0.8942 - recall: 0.8597 - val_loss: 0.8335 - val_iou_score: 0.1278 - val_f1-score: 0.8615 - val_precision: 0.8786 - val_recall: 0.8558 - lr: 0.0010
# Epoch 30/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8214 - iou_score: 0.1421 - f1-score: 0.8770 - precision: 0.8969 - recall: 0.8632 - val_loss: 0.8403 - val_iou_score: 0.1208 - val_f1-score: 0.8436 - val_precision: 0.9073 - val_recall: 0.8004 - lr: 0.0010
# Epoch 31/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8218 - iou_score: 0.1416 - f1-score: 0.8732 - precision: 0.8940 - recall: 0.8591 - val_loss: 0.8361 - val_iou_score: 0.1247 - val_f1-score: 0.8589 - val_precision: 0.8992 - val_recall: 0.8316 - lr: 0.0010
# Epoch 32/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8205 - iou_score: 0.1426 - f1-score: 0.8771 - precision: 0.8977 - recall: 0.8628 - val_loss: 0.8310 - val_iou_score: 0.1308 - val_f1-score: 0.8622 - val_precision: 0.8758 - val_recall: 0.8572 - lr: 0.0010
# Epoch 33/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8191 - iou_score: 0.1445 - f1-score: 0.8803 - precision: 0.9015 - recall: 0.8658 - val_loss: 0.8334 - val_iou_score: 0.1276 - val_f1-score: 0.8627 - val_precision: 0.9079 - val_recall: 0.8319 - lr: 0.0010
# Epoch 34/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8192 - iou_score: 0.1446 - f1-score: 0.8798 - precision: 0.9010 - recall: 0.8662 - val_loss: 0.8297 - val_iou_score: 0.1316 - val_f1-score: 0.8688 - val_precision: 0.8947 - val_recall: 0.8505 - lr: 0.0010
# Epoch 35/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8180 - iou_score: 0.1458 - f1-score: 0.8827 - precision: 0.9042 - recall: 0.8676 - val_loss: 0.8292 - val_iou_score: 0.1318 - val_f1-score: 0.8713 - val_precision: 0.9061 - val_recall: 0.8451 - lr: 0.0010
# Epoch 36/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8168 - iou_score: 0.1470 - f1-score: 0.8844 - precision: 0.9061 - recall: 0.8696 - val_loss: 0.8310 - val_iou_score: 0.1300 - val_f1-score: 0.8668 - val_precision: 0.9135 - val_recall: 0.8348 - lr: 0.0010
# Epoch 37/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8201 - iou_score: 0.1440 - f1-score: 0.8750 - precision: 0.8969 - recall: 0.8605 - val_loss: 0.8323 - val_iou_score: 0.1314 - val_f1-score: 0.8395 - val_precision: 0.8815 - val_recall: 0.8109 - lr: 0.0010
# Epoch 38/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8172 - iou_score: 0.1468 - f1-score: 0.8809 - precision: 0.9026 - recall: 0.8659 - val_loss: 0.8297 - val_iou_score: 0.1318 - val_f1-score: 0.8651 - val_precision: 0.8736 - val_recall: 0.8643 - lr: 0.0010
# Epoch 39/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8153 - iou_score: 0.1490 - f1-score: 0.8856 - precision: 0.9070 - recall: 0.8709 - val_loss: 0.8283 - val_iou_score: 0.1331 - val_f1-score: 0.8721 - val_precision: 0.9083 - val_recall: 0.8458 - lr: 0.0010
# Epoch 40/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8154 - iou_score: 0.1489 - f1-score: 0.8866 - precision: 0.9087 - recall: 0.8713 - val_loss: 0.8292 - val_iou_score: 0.1318 - val_f1-score: 0.8733 - val_precision: 0.9132 - val_recall: 0.8478 - lr: 0.0010
# Epoch 41/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8144 - iou_score: 0.1500 - f1-score: 0.8886 - precision: 0.9110 - recall: 0.8734 - val_loss: 0.8257 - val_iou_score: 0.1362 - val_f1-score: 0.8732 - val_precision: 0.8985 - val_recall: 0.8546 - lr: 0.0010
# Epoch 42/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8139 - iou_score: 0.1508 - f1-score: 0.8884 - precision: 0.9107 - recall: 0.8729 - val_loss: 0.8292 - val_iou_score: 0.1320 - val_f1-score: 0.8726 - val_precision: 0.9072 - val_recall: 0.8511 - lr: 0.0010
# Epoch 43/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8119 - iou_score: 0.1527 - f1-score: 0.8916 - precision: 0.9123 - recall: 0.8767 - val_loss: 0.8354 - val_iou_score: 0.1254 - val_f1-score: 0.8617 - val_precision: 0.9151 - val_recall: 0.8272 - lr: 0.0010
# Epoch 44/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8146 - iou_score: 0.1500 - f1-score: 0.8862 - precision: 0.9086 - recall: 0.8705 - val_loss: 0.8273 - val_iou_score: 0.1339 - val_f1-score: 0.8746 - val_precision: 0.9038 - val_recall: 0.8538 - lr: 0.0010
# Epoch 45/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8126 - iou_score: 0.1520 - f1-score: 0.8903 - precision: 0.9129 - recall: 0.8748 - val_loss: 0.8252 - val_iou_score: 0.1364 - val_f1-score: 0.8775 - val_precision: 0.8865 - val_recall: 0.8731 - lr: 0.0010
# Epoch 46/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8115 - iou_score: 0.1537 - f1-score: 0.8925 - precision: 0.9136 - recall: 0.8778 - val_loss: 0.8279 - val_iou_score: 0.1336 - val_f1-score: 0.8717 - val_precision: 0.9156 - val_recall: 0.8401 - lr: 0.0010
# Epoch 47/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8116 - iou_score: 0.1534 - f1-score: 0.8918 - precision: 0.9145 - recall: 0.8760 - val_loss: 0.8319 - val_iou_score: 0.1293 - val_f1-score: 0.8602 - val_precision: 0.9173 - val_recall: 0.8217 - lr: 0.0010
# Epoch 48/100
# 180/180 [==============================] - 73s 404ms/step - loss: 0.8115 - iou_score: 0.1534 - f1-score: 0.8909 - precision: 0.9127 - recall: 0.8757 - val_loss: 0.8299 - val_iou_score: 0.1310 - val_f1-score: 0.8732 - val_precision: 0.9204 - val_recall: 0.8432 - lr: 0.0010
# Epoch 49/100
# 180/180 [==============================] - 73s 404ms/step - loss: 0.8118 - iou_score: 0.1534 - f1-score: 0.8914 - precision: 0.9127 - recall: 0.8768 - val_loss: 0.8277 - val_iou_score: 0.1333 - val_f1-score: 0.8758 - val_precision: 0.8942 - val_recall: 0.8652 - lr: 0.0010
# Epoch 50/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8096 - iou_score: 0.1556 - f1-score: 0.8958 - precision: 0.9173 - recall: 0.8805 - val_loss: 0.8325 - val_iou_score: 0.1282 - val_f1-score: 0.8717 - val_precision: 0.9116 - val_recall: 0.8499 - lr: 0.0010
# Epoch 51/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8095 - iou_score: 0.1563 - f1-score: 0.8951 - precision: 0.9172 - recall: 0.8794 - val_loss: 0.8304 - val_iou_score: 0.1308 - val_f1-score: 0.8705 - val_precision: 0.9022 - val_recall: 0.8496 - lr: 0.0010
# Epoch 52/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8101 - iou_score: 0.1554 - f1-score: 0.8949 - precision: 0.9160 - recall: 0.8802 - val_loss: 0.8294 - val_iou_score: 0.1317 - val_f1-score: 0.8734 - val_precision: 0.9076 - val_recall: 0.8519 - lr: 0.0010
# Epoch 53/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8086 - iou_score: 0.1572 - f1-score: 0.8966 - precision: 0.9184 - recall: 0.8818 - val_loss: 0.8263 - val_iou_score: 0.1352 - val_f1-score: 0.8750 - val_precision: 0.8997 - val_recall: 0.8598 - lr: 0.0010
# Epoch 54/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8090 - iou_score: 0.1572 - f1-score: 0.8943 - precision: 0.9155 - recall: 0.8797 - val_loss: 0.8277 - val_iou_score: 0.1339 - val_f1-score: 0.8742 - val_precision: 0.9238 - val_recall: 0.8406 - lr: 0.0010
# Epoch 55/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8092 - iou_score: 0.1566 - f1-score: 0.8928 - precision: 0.9156 - recall: 0.8768 - val_loss: 0.8242 - val_iou_score: 0.1379 - val_f1-score: 0.8761 - val_precision: 0.9072 - val_recall: 0.8536 - lr: 0.0010
# Epoch 56/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8080 - iou_score: 0.1582 - f1-score: 0.8975 - precision: 0.9186 - recall: 0.8828 - val_loss: 0.8237 - val_iou_score: 0.1378 - val_f1-score: 0.8813 - val_precision: 0.9123 - val_recall: 0.8603 - lr: 0.0010
# Epoch 57/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8068 - iou_score: 0.1595 - f1-score: 0.8996 - precision: 0.9211 - recall: 0.8844 - val_loss: 0.8234 - val_iou_score: 0.1386 - val_f1-score: 0.8808 - val_precision: 0.9010 - val_recall: 0.8704 - lr: 0.0010
# Epoch 58/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8054 - iou_score: 0.1614 - f1-score: 0.9018 - precision: 0.9232 - recall: 0.8861 - val_loss: 0.8242 - val_iou_score: 0.1376 - val_f1-score: 0.8802 - val_precision: 0.9130 - val_recall: 0.8575 - lr: 0.0010
# Epoch 59/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8061 - iou_score: 0.1605 - f1-score: 0.8998 - precision: 0.9218 - recall: 0.8840 - val_loss: 0.8244 - val_iou_score: 0.1375 - val_f1-score: 0.8788 - val_precision: 0.9195 - val_recall: 0.8511 - lr: 0.0010
# Epoch 60/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8057 - iou_score: 0.1611 - f1-score: 0.9006 - precision: 0.9228 - recall: 0.8853 - val_loss: 0.8234 - val_iou_score: 0.1386 - val_f1-score: 0.8810 - val_precision: 0.9156 - val_recall: 0.8562 - lr: 0.0010
# Epoch 61/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8050 - iou_score: 0.1617 - f1-score: 0.9012 - precision: 0.9226 - recall: 0.8859 - val_loss: 0.8222 - val_iou_score: 0.1398 - val_f1-score: 0.8838 - val_precision: 0.9147 - val_recall: 0.8657 - lr: 0.0010
# Epoch 62/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8051 - iou_score: 0.1620 - f1-score: 0.9009 - precision: 0.9225 - recall: 0.8858 - val_loss: 0.8240 - val_iou_score: 0.1378 - val_f1-score: 0.8773 - val_precision: 0.8998 - val_recall: 0.8610 - lr: 0.0010
# Epoch 63/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8044 - iou_score: 0.1624 - f1-score: 0.9022 - precision: 0.9238 - recall: 0.8868 - val_loss: 0.8262 - val_iou_score: 0.1351 - val_f1-score: 0.8795 - val_precision: 0.9153 - val_recall: 0.8562 - lr: 0.0010
# Epoch 64/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8033 - iou_score: 0.1635 - f1-score: 0.9043 - precision: 0.9257 - recall: 0.8886 - val_loss: 0.8256 - val_iou_score: 0.1361 - val_f1-score: 0.8756 - val_precision: 0.9012 - val_recall: 0.8610 - lr: 0.0010
# Epoch 65/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8042 - iou_score: 0.1629 - f1-score: 0.9022 - precision: 0.9245 - recall: 0.8870 - val_loss: 0.8237 - val_iou_score: 0.1397 - val_f1-score: 0.8591 - val_precision: 0.8941 - val_recall: 0.8357 - lr: 0.0010
# Epoch 66/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8031 - iou_score: 0.1643 - f1-score: 0.9042 - precision: 0.9261 - recall: 0.8887 - val_loss: 0.8262 - val_iou_score: 0.1353 - val_f1-score: 0.8805 - val_precision: 0.9234 - val_recall: 0.8528 - lr: 0.0010
# Epoch 67/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8024 - iou_score: 0.1656 - f1-score: 0.9058 - precision: 0.9269 - recall: 0.8910 - val_loss: 0.8221 - val_iou_score: 0.1397 - val_f1-score: 0.8842 - val_precision: 0.9130 - val_recall: 0.8640 - lr: 0.0010
# Epoch 68/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8016 - iou_score: 0.1659 - f1-score: 0.9064 - precision: 0.9274 - recall: 0.8909 - val_loss: 0.8218 - val_iou_score: 0.1406 - val_f1-score: 0.8843 - val_precision: 0.9114 - val_recall: 0.8674 - lr: 0.0010
# Epoch 69/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8032 - iou_score: 0.1645 - f1-score: 0.9040 - precision: 0.9255 - recall: 0.8898 - val_loss: 0.8213 - val_iou_score: 0.1412 - val_f1-score: 0.8822 - val_precision: 0.9045 - val_recall: 0.8660 - lr: 0.0010
# Epoch 70/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8019 - iou_score: 0.1660 - f1-score: 0.9060 - precision: 0.9273 - recall: 0.8907 - val_loss: 0.8211 - val_iou_score: 0.1413 - val_f1-score: 0.8842 - val_precision: 0.9036 - val_recall: 0.8733 - lr: 0.0010
# Epoch 71/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8010 - iou_score: 0.1673 - f1-score: 0.9075 - precision: 0.9278 - recall: 0.8928 - val_loss: 0.8208 - val_iou_score: 0.1415 - val_f1-score: 0.8831 - val_precision: 0.9024 - val_recall: 0.8702 - lr: 0.0010
# Epoch 72/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8004 - iou_score: 0.1680 - f1-score: 0.9083 - precision: 0.9303 - recall: 0.8926 - val_loss: 0.8227 - val_iou_score: 0.1392 - val_f1-score: 0.8830 - val_precision: 0.9188 - val_recall: 0.8563 - lr: 0.0010
# Epoch 73/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8013 - iou_score: 0.1670 - f1-score: 0.9061 - precision: 0.9277 - recall: 0.8902 - val_loss: 0.8233 - val_iou_score: 0.1387 - val_f1-score: 0.8792 - val_precision: 0.9142 - val_recall: 0.8530 - lr: 0.0010
# Epoch 74/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8012 - iou_score: 0.1673 - f1-score: 0.9068 - precision: 0.9281 - recall: 0.8922 - val_loss: 0.8194 - val_iou_score: 0.1429 - val_f1-score: 0.8826 - val_precision: 0.9161 - val_recall: 0.8564 - lr: 0.0010
# Epoch 75/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7994 - iou_score: 0.1691 - f1-score: 0.9097 - precision: 0.9309 - recall: 0.8945 - val_loss: 0.8216 - val_iou_score: 0.1404 - val_f1-score: 0.8850 - val_precision: 0.9116 - val_recall: 0.8677 - lr: 0.0010
# Epoch 76/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7998 - iou_score: 0.1689 - f1-score: 0.9090 - precision: 0.9311 - recall: 0.8933 - val_loss: 0.8225 - val_iou_score: 0.1399 - val_f1-score: 0.8855 - val_precision: 0.9172 - val_recall: 0.8657 - lr: 0.0010
# Epoch 77/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7994 - iou_score: 0.1696 - f1-score: 0.9100 - precision: 0.9314 - recall: 0.8947 - val_loss: 0.8210 - val_iou_score: 0.1411 - val_f1-score: 0.8857 - val_precision: 0.9131 - val_recall: 0.8690 - lr: 0.0010
# Epoch 78/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7992 - iou_score: 0.1696 - f1-score: 0.9102 - precision: 0.9309 - recall: 0.8956 - val_loss: 0.8224 - val_iou_score: 0.1397 - val_f1-score: 0.8843 - val_precision: 0.9102 - val_recall: 0.8664 - lr: 0.0010
# Epoch 79/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7981 - iou_score: 0.1713 - f1-score: 0.9114 - precision: 0.9321 - recall: 0.8964 - val_loss: 0.8194 - val_iou_score: 0.1437 - val_f1-score: 0.8856 - val_precision: 0.9127 - val_recall: 0.8672 - lr: 0.0010
# Epoch 80/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8008 - iou_score: 0.1676 - f1-score: 0.9054 - precision: 0.9263 - recall: 0.8906 - val_loss: 0.8279 - val_iou_score: 0.1345 - val_f1-score: 0.8696 - val_precision: 0.8957 - val_recall: 0.8514 - lr: 0.0010
# Epoch 81/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8007 - iou_score: 0.1681 - f1-score: 0.9057 - precision: 0.9258 - recall: 0.8917 - val_loss: 0.8229 - val_iou_score: 0.1392 - val_f1-score: 0.8841 - val_precision: 0.9173 - val_recall: 0.8615 - lr: 0.0010
# Epoch 82/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7980 - iou_score: 0.1715 - f1-score: 0.9116 - precision: 0.9319 - recall: 0.8969 - val_loss: 0.8207 - val_iou_score: 0.1415 - val_f1-score: 0.8860 - val_precision: 0.9107 - val_recall: 0.8679 - lr: 0.0010
# Epoch 83/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7983 - iou_score: 0.1709 - f1-score: 0.9105 - precision: 0.9310 - recall: 0.8958 - val_loss: 0.8220 - val_iou_score: 0.1401 - val_f1-score: 0.8839 - val_precision: 0.9198 - val_recall: 0.8580 - lr: 0.0010
# Epoch 84/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7980 - iou_score: 0.1715 - f1-score: 0.9122 - precision: 0.9329 - recall: 0.8974 - val_loss: 0.8234 - val_iou_score: 0.1388 - val_f1-score: 0.8833 - val_precision: 0.9269 - val_recall: 0.8536 - lr: 0.0010
# Epoch 85/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7946 - iou_score: 0.1756 - f1-score: 0.9171 - precision: 0.9393 - recall: 0.9011 - val_loss: 0.8189 - val_iou_score: 0.1436 - val_f1-score: 0.8906 - val_precision: 0.9267 - val_recall: 0.8661 - lr: 1.0000e-04
# Epoch 86/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7929 - iou_score: 0.1786 - f1-score: 0.9200 - precision: 0.9419 - recall: 0.9042 - val_loss: 0.8184 - val_iou_score: 0.1445 - val_f1-score: 0.8913 - val_precision: 0.9279 - val_recall: 0.8665 - lr: 1.0000e-04
# Epoch 87/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7919 - iou_score: 0.1800 - f1-score: 0.9213 - precision: 0.9434 - recall: 0.9051 - val_loss: 0.8176 - val_iou_score: 0.1453 - val_f1-score: 0.8921 - val_precision: 0.9237 - val_recall: 0.8705 - lr: 1.0000e-04
# Epoch 88/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7915 - iou_score: 0.1809 - f1-score: 0.9218 - precision: 0.9441 - recall: 0.9057 - val_loss: 0.8176 - val_iou_score: 0.1455 - val_f1-score: 0.8922 - val_precision: 0.9273 - val_recall: 0.8684 - lr: 1.0000e-04
# Epoch 89/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7913 - iou_score: 0.1809 - f1-score: 0.9217 - precision: 0.9453 - recall: 0.9052 - val_loss: 0.8176 - val_iou_score: 0.1455 - val_f1-score: 0.8920 - val_precision: 0.9274 - val_recall: 0.8680 - lr: 1.0000e-04
# Epoch 90/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7904 - iou_score: 0.1825 - f1-score: 0.9230 - precision: 0.9458 - recall: 0.9067 - val_loss: 0.8176 - val_iou_score: 0.1454 - val_f1-score: 0.8924 - val_precision: 0.9241 - val_recall: 0.8713 - lr: 1.0000e-04
# Epoch 91/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.7900 - iou_score: 0.1830 - f1-score: 0.9235 - precision: 0.9463 - recall: 0.9070 - val_loss: 0.8173 - val_iou_score: 0.1460 - val_f1-score: 0.8927 - val_precision: 0.9262 - val_recall: 0.8705 - lr: 1.0000e-04
# Epoch 92/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7898 - iou_score: 0.1835 - f1-score: 0.9239 - precision: 0.9469 - recall: 0.9074 - val_loss: 0.8173 - val_iou_score: 0.1459 - val_f1-score: 0.8926 - val_precision: 0.9283 - val_recall: 0.8689 - lr: 1.0000e-04
# Epoch 93/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7894 - iou_score: 0.1840 - f1-score: 0.9245 - precision: 0.9476 - recall: 0.9077 - val_loss: 0.8169 - val_iou_score: 0.1463 - val_f1-score: 0.8931 - val_precision: 0.9278 - val_recall: 0.8698 - lr: 1.0000e-04
# Epoch 94/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7892 - iou_score: 0.1842 - f1-score: 0.9248 - precision: 0.9478 - recall: 0.9079 - val_loss: 0.8167 - val_iou_score: 0.1467 - val_f1-score: 0.8933 - val_precision: 0.9292 - val_recall: 0.8688 - lr: 1.0000e-04
# Epoch 95/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7891 - iou_score: 0.1844 - f1-score: 0.9248 - precision: 0.9485 - recall: 0.9079 - val_loss: 0.8166 - val_iou_score: 0.1467 - val_f1-score: 0.8934 - val_precision: 0.9292 - val_recall: 0.8691 - lr: 1.0000e-04
# Epoch 96/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7891 - iou_score: 0.1846 - f1-score: 0.9248 - precision: 0.9485 - recall: 0.9078 - val_loss: 0.8165 - val_iou_score: 0.1469 - val_f1-score: 0.8934 - val_precision: 0.9295 - val_recall: 0.8691 - lr: 1.0000e-04
# Epoch 97/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7886 - iou_score: 0.1853 - f1-score: 0.9254 - precision: 0.9491 - recall: 0.9085 - val_loss: 0.8163 - val_iou_score: 0.1471 - val_f1-score: 0.8937 - val_precision: 0.9272 - val_recall: 0.8713 - lr: 1.0000e-04
# Epoch 98/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7884 - iou_score: 0.1856 - f1-score: 0.9258 - precision: 0.9494 - recall: 0.9088 - val_loss: 0.8167 - val_iou_score: 0.1467 - val_f1-score: 0.8933 - val_precision: 0.9302 - val_recall: 0.8684 - lr: 1.0000e-04
# Epoch 99/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7884 - iou_score: 0.1857 - f1-score: 0.9258 - precision: 0.9496 - recall: 0.9088 - val_loss: 0.8161 - val_iou_score: 0.1475 - val_f1-score: 0.8940 - val_precision: 0.9294 - val_recall: 0.8700 - lr: 1.0000e-04
# Epoch 100/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7882 - iou_score: 0.1860 - f1-score: 0.9261 - precision: 0.9498 - recall: 0.9091 - val_loss: 0.8164 - val_iou_score: 0.1473 - val_f1-score: 0.8938 - val_precision: 0.9300 - val_recall: 0.8692 - lr: 1.0000e-04

# %%
model_in_mem.save('unet_softmax_1500_vgg16.hdf5')
from google.colab import files
files.download('unet_softmax_1500_vgg16.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
#model = load_model('/content/psp_softmax_1500_seresnet50.hdf5', compile=False)
model = model_in_mem

# IoU
X_test = preprocess_input(X_test)
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 2s 413ms/step
# Mean IoU = 0.5004524
# [[1.6162637e+07 1.9748000e+04 1.1807600e+05 3.6000000e+01]
#  [2.1346900e+05 2.8498900e+05 2.2780000e+04 9.5500000e+02]
#  [3.6472340e+06 1.2604000e+04 3.0968470e+06 1.0000000e+01]
#  [4.2860000e+03 3.7640000e+03 2.0120000e+03 3.5130000e+03]]
# IoU for class1 is:  0.8015
# IoU for class2 is:  0.5104503
# IoU for class3 is:  0.44884685
# IoU for class4 is:  0.24101262

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, vmin=0, vmax=3, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
