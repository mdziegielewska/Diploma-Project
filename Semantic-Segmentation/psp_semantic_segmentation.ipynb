# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Requirement already satisfied: segmentation-models in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.25.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# []

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/results"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'resnet50'
preprocess_input = sm.get_preprocessing(BACKBONE)

# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
# model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=15)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=32,
        epochs=100,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet50_imagenet_1000_no_top.h5
# 94592056/94592056 [==============================] - 1s 0us/step
# Epoch 1/100
# 45/45 [==============================] - 413s 9s/step - loss: 0.9847 - iou_score: 0.0166 - f1-score: 0.5659 - precision: 0.7188 - recall: 0.5578 - val_loss: 1.0116 - val_iou_score: 0.0425 - val_f1-score: 0.3139 - val_precision: 0.6854 - val_recall: 0.3340 - lr: 0.0010
# Epoch 2/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.8755 - iou_score: 0.0890 - f1-score: 0.7349 - precision: 0.7764 - recall: 0.7164 - val_loss: 1.0260 - val_iou_score: 6.1298e-04 - val_f1-score: 0.2211 - val_precision: 0.8599 - val_recall: 0.2584 - lr: 0.0010
# Epoch 3/100
# 45/45 [==============================] - 410s 9s/step - loss: 0.8476 - iou_score: 0.1140 - f1-score: 0.8204 - precision: 0.8430 - recall: 0.8046 - val_loss: 0.9238 - val_iou_score: 0.0553 - val_f1-score: 0.4392 - val_precision: 0.6809 - val_recall: 0.4116 - lr: 0.0010
# Epoch 4/100
# 45/45 [==============================] - 414s 9s/step - loss: 0.8409 - iou_score: 0.1205 - f1-score: 0.8343 - precision: 0.8575 - recall: 0.8176 - val_loss: 0.9151 - val_iou_score: 0.0712 - val_f1-score: 0.4198 - val_precision: 0.7818 - val_recall: 0.3918 - lr: 0.0010
# Epoch 5/100
# 45/45 [==============================] - 413s 9s/step - loss: 0.8345 - iou_score: 0.1271 - f1-score: 0.8462 - precision: 0.8671 - recall: 0.8306 - val_loss: 0.9104 - val_iou_score: 0.0706 - val_f1-score: 0.4444 - val_precision: 0.8501 - val_recall: 0.4046 - lr: 0.0010
# Epoch 6/100
# 45/45 [==============================] - 412s 9s/step - loss: 0.8267 - iou_score: 0.1352 - f1-score: 0.8659 - precision: 0.8849 - recall: 0.8507 - val_loss: 0.8695 - val_iou_score: 0.1078 - val_f1-score: 0.6167 - val_precision: 0.8680 - val_recall: 0.5506 - lr: 0.0010
# Epoch 7/100
# 45/45 [==============================] - 418s 9s/step - loss: 0.8253 - iou_score: 0.1365 - f1-score: 0.8681 - precision: 0.8856 - recall: 0.8535 - val_loss: 0.8712 - val_iou_score: 0.0940 - val_f1-score: 0.7299 - val_precision: 0.9167 - val_recall: 0.6402 - lr: 0.0010
# Epoch 8/100
# 45/45 [==============================] - 417s 9s/step - loss: 0.8217 - iou_score: 0.1406 - f1-score: 0.8756 - precision: 0.8943 - recall: 0.8601 - val_loss: 0.8685 - val_iou_score: 0.0952 - val_f1-score: 0.7173 - val_precision: 0.9232 - val_recall: 0.6354 - lr: 0.0010
# Epoch 9/100
# 45/45 [==============================] - 409s 9s/step - loss: 0.8212 - iou_score: 0.1412 - f1-score: 0.8759 - precision: 0.8914 - recall: 0.8637 - val_loss: 0.8492 - val_iou_score: 0.1138 - val_f1-score: 0.7960 - val_precision: 0.9120 - val_recall: 0.7239 - lr: 0.0010
# Epoch 10/100
# 45/45 [==============================] - 399s 9s/step - loss: 0.8182 - iou_score: 0.1445 - f1-score: 0.8804 - precision: 0.8974 - recall: 0.8672 - val_loss: 0.8392 - val_iou_score: 0.1215 - val_f1-score: 0.8451 - val_precision: 0.8771 - val_recall: 0.8203 - lr: 0.0010
# Epoch 11/100
# 45/45 [==============================] - 425s 9s/step - loss: 0.8186 - iou_score: 0.1442 - f1-score: 0.8790 - precision: 0.8981 - recall: 0.8641 - val_loss: 0.8372 - val_iou_score: 0.1234 - val_f1-score: 0.8503 - val_precision: 0.9065 - val_recall: 0.8072 - lr: 0.0010
# Epoch 12/100
# 45/45 [==============================] - 433s 10s/step - loss: 0.8149 - iou_score: 0.1487 - f1-score: 0.8864 - precision: 0.9040 - recall: 0.8718 - val_loss: 0.8295 - val_iou_score: 0.1311 - val_f1-score: 0.8637 - val_precision: 0.9028 - val_recall: 0.8312 - lr: 0.0010
# Epoch 13/100
# 45/45 [==============================] - 425s 9s/step - loss: 0.8129 - iou_score: 0.1509 - f1-score: 0.8894 - precision: 0.9073 - recall: 0.8751 - val_loss: 0.8263 - val_iou_score: 0.1351 - val_f1-score: 0.8720 - val_precision: 0.9059 - val_recall: 0.8449 - lr: 0.0010
# Epoch 14/100
# 45/45 [==============================] - 428s 10s/step - loss: 0.8120 - iou_score: 0.1522 - f1-score: 0.8909 - precision: 0.9091 - recall: 0.8762 - val_loss: 0.8271 - val_iou_score: 0.1345 - val_f1-score: 0.8714 - val_precision: 0.8855 - val_recall: 0.8587 - lr: 0.0010
# Epoch 15/100
# 45/45 [==============================] - 425s 9s/step - loss: 0.8113 - iou_score: 0.1530 - f1-score: 0.8926 - precision: 0.9103 - recall: 0.8783 - val_loss: 0.8241 - val_iou_score: 0.1378 - val_f1-score: 0.8754 - val_precision: 0.8975 - val_recall: 0.8561 - lr: 0.0010
# Epoch 16/100
# 45/45 [==============================] - 436s 10s/step - loss: 0.8093 - iou_score: 0.1553 - f1-score: 0.8945 - precision: 0.9120 - recall: 0.8806 - val_loss: 0.8252 - val_iou_score: 0.1369 - val_f1-score: 0.8714 - val_precision: 0.8966 - val_recall: 0.8500 - lr: 0.0010
# Epoch 17/100
# 45/45 [==============================] - 421s 9s/step - loss: 0.8081 - iou_score: 0.1568 - f1-score: 0.8970 - precision: 0.9146 - recall: 0.8826 - val_loss: 0.8232 - val_iou_score: 0.1402 - val_f1-score: 0.8637 - val_precision: 0.9046 - val_recall: 0.8297 - lr: 0.0010
# Epoch 18/100
# 45/45 [==============================] - 405s 9s/step - loss: 0.8067 - iou_score: 0.1589 - f1-score: 0.8988 - precision: 0.9169 - recall: 0.8840 - val_loss: 0.8259 - val_iou_score: 0.1349 - val_f1-score: 0.8716 - val_precision: 0.9019 - val_recall: 0.8463 - lr: 0.0010
# Epoch 19/100
# 45/45 [==============================] - 404s 9s/step - loss: 0.8072 - iou_score: 0.1583 - f1-score: 0.8975 - precision: 0.9159 - recall: 0.8827 - val_loss: 0.8268 - val_iou_score: 0.1345 - val_f1-score: 0.8630 - val_precision: 0.9172 - val_recall: 0.8221 - lr: 0.0010
# Epoch 20/100
# 45/45 [==============================] - 412s 9s/step - loss: 0.8058 - iou_score: 0.1600 - f1-score: 0.8995 - precision: 0.9188 - recall: 0.8839 - val_loss: 0.8263 - val_iou_score: 0.1351 - val_f1-score: 0.8728 - val_precision: 0.9213 - val_recall: 0.8351 - lr: 0.0010
# Epoch 21/100
# 45/45 [==============================] - 409s 9s/step - loss: 0.8056 - iou_score: 0.1602 - f1-score: 0.8998 - precision: 0.9171 - recall: 0.8858 - val_loss: 0.8218 - val_iou_score: 0.1416 - val_f1-score: 0.8694 - val_precision: 0.9117 - val_recall: 0.8342 - lr: 0.0010
# Epoch 22/100
# 45/45 [==============================] - 408s 9s/step - loss: 0.8040 - iou_score: 0.1623 - f1-score: 0.9022 - precision: 0.9200 - recall: 0.8875 - val_loss: 0.8244 - val_iou_score: 0.1375 - val_f1-score: 0.8743 - val_precision: 0.8919 - val_recall: 0.8623 - lr: 0.0010
# Epoch 23/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.8037 - iou_score: 0.1627 - f1-score: 0.9023 - precision: 0.9198 - recall: 0.8885 - val_loss: 0.8224 - val_iou_score: 0.1394 - val_f1-score: 0.8723 - val_precision: 0.9207 - val_recall: 0.8336 - lr: 0.0010
# Epoch 24/100
# 45/45 [==============================] - 412s 9s/step - loss: 0.8031 - iou_score: 0.1634 - f1-score: 0.9035 - precision: 0.9204 - recall: 0.8898 - val_loss: 0.8202 - val_iou_score: 0.1418 - val_f1-score: 0.8731 - val_precision: 0.9138 - val_recall: 0.8402 - lr: 0.0010
# Epoch 25/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.8022 - iou_score: 0.1647 - f1-score: 0.9038 - precision: 0.9224 - recall: 0.8885 - val_loss: 0.8235 - val_iou_score: 0.1382 - val_f1-score: 0.8786 - val_precision: 0.9028 - val_recall: 0.8585 - lr: 0.0010
# Epoch 26/100
# 45/45 [==============================] - 416s 9s/step - loss: 0.8013 - iou_score: 0.1661 - f1-score: 0.9058 - precision: 0.9221 - recall: 0.8930 - val_loss: 0.8264 - val_iou_score: 0.1344 - val_f1-score: 0.8728 - val_precision: 0.9228 - val_recall: 0.8348 - lr: 0.0010
# Epoch 27/100
# 45/45 [==============================] - 408s 9s/step - loss: 0.7999 - iou_score: 0.1676 - f1-score: 0.9084 - precision: 0.9265 - recall: 0.8933 - val_loss: 0.8223 - val_iou_score: 0.1392 - val_f1-score: 0.8802 - val_precision: 0.8883 - val_recall: 0.8737 - lr: 0.0010
# Epoch 28/100
# 45/45 [==============================] - 407s 9s/step - loss: 0.8002 - iou_score: 0.1674 - f1-score: 0.9077 - precision: 0.9251 - recall: 0.8935 - val_loss: 0.8242 - val_iou_score: 0.1375 - val_f1-score: 0.8740 - val_precision: 0.9098 - val_recall: 0.8460 - lr: 0.0010
# Epoch 29/100
# 45/45 [==============================] - 404s 9s/step - loss: 0.7986 - iou_score: 0.1693 - f1-score: 0.9099 - precision: 0.9278 - recall: 0.8949 - val_loss: 0.8221 - val_iou_score: 0.1395 - val_f1-score: 0.8794 - val_precision: 0.8953 - val_recall: 0.8692 - lr: 0.0010
# Epoch 30/100
# 45/45 [==============================] - 404s 9s/step - loss: 0.7978 - iou_score: 0.1705 - f1-score: 0.9104 - precision: 0.9293 - recall: 0.8950 - val_loss: 0.8218 - val_iou_score: 0.1405 - val_f1-score: 0.8746 - val_precision: 0.8674 - val_recall: 0.8865 - lr: 0.0010
# Epoch 31/100
# 45/45 [==============================] - 403s 9s/step - loss: 0.7980 - iou_score: 0.1701 - f1-score: 0.9103 - precision: 0.9272 - recall: 0.8962 - val_loss: 0.8223 - val_iou_score: 0.1400 - val_f1-score: 0.8746 - val_precision: 0.8742 - val_recall: 0.8772 - lr: 0.0010
# Epoch 32/100
# 45/45 [==============================] - 403s 9s/step - loss: 0.7982 - iou_score: 0.1702 - f1-score: 0.9097 - precision: 0.9280 - recall: 0.8951 - val_loss: 0.8221 - val_iou_score: 0.1406 - val_f1-score: 0.8700 - val_precision: 0.8944 - val_recall: 0.8523 - lr: 0.0010
# Epoch 33/100
# 45/45 [==============================] - 408s 9s/step - loss: 0.7974 - iou_score: 0.1712 - f1-score: 0.9103 - precision: 0.9273 - recall: 0.8964 - val_loss: 0.8248 - val_iou_score: 0.1368 - val_f1-score: 0.8776 - val_precision: 0.9051 - val_recall: 0.8572 - lr: 0.0010
# Epoch 34/100
# 45/45 [==============================] - 410s 9s/step - loss: 0.7974 - iou_score: 0.1712 - f1-score: 0.9109 - precision: 0.9288 - recall: 0.8963 - val_loss: 0.8228 - val_iou_score: 0.1392 - val_f1-score: 0.8789 - val_precision: 0.8958 - val_recall: 0.8669 - lr: 0.0010
# Epoch 35/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.7940 - iou_score: 0.1757 - f1-score: 0.9168 - precision: 0.9324 - recall: 0.9037 - val_loss: 0.8175 - val_iou_score: 0.1448 - val_f1-score: 0.8909 - val_precision: 0.9107 - val_recall: 0.8744 - lr: 1.0000e-04
# Epoch 36/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.7916 - iou_score: 0.1792 - f1-score: 0.9207 - precision: 0.9394 - recall: 0.9050 - val_loss: 0.8152 - val_iou_score: 0.1476 - val_f1-score: 0.8940 - val_precision: 0.9133 - val_recall: 0.8777 - lr: 1.0000e-04
# Epoch 37/100
# 45/45 [==============================] - 413s 9s/step - loss: 0.7903 - iou_score: 0.1813 - f1-score: 0.9225 - precision: 0.9409 - recall: 0.9069 - val_loss: 0.8146 - val_iou_score: 0.1488 - val_f1-score: 0.8955 - val_precision: 0.9172 - val_recall: 0.8776 - lr: 1.0000e-04
# Epoch 38/100
# 45/45 [==============================] - 410s 9s/step - loss: 0.7898 - iou_score: 0.1822 - f1-score: 0.9231 - precision: 0.9426 - recall: 0.9068 - val_loss: 0.8140 - val_iou_score: 0.1498 - val_f1-score: 0.8964 - val_precision: 0.9165 - val_recall: 0.8798 - lr: 1.0000e-04
# Epoch 39/100
# 45/45 [==============================] - 413s 9s/step - loss: 0.7889 - iou_score: 0.1835 - f1-score: 0.9242 - precision: 0.9435 - recall: 0.9080 - val_loss: 0.8141 - val_iou_score: 0.1495 - val_f1-score: 0.8959 - val_precision: 0.9208 - val_recall: 0.8756 - lr: 1.0000e-04
# Epoch 40/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.7885 - iou_score: 0.1843 - f1-score: 0.9248 - precision: 0.9445 - recall: 0.9084 - val_loss: 0.8138 - val_iou_score: 0.1498 - val_f1-score: 0.8961 - val_precision: 0.9211 - val_recall: 0.8760 - lr: 1.0000e-04
# Epoch 41/100
# 45/45 [==============================] - 410s 9s/step - loss: 0.7878 - iou_score: 0.1850 - f1-score: 0.9254 - precision: 0.9451 - recall: 0.9088 - val_loss: 0.8138 - val_iou_score: 0.1497 - val_f1-score: 0.8963 - val_precision: 0.9216 - val_recall: 0.8763 - lr: 1.0000e-04
# Epoch 42/100
# 45/45 [==============================] - 410s 9s/step - loss: 0.7877 - iou_score: 0.1854 - f1-score: 0.9256 - precision: 0.9454 - recall: 0.9093 - val_loss: 0.8132 - val_iou_score: 0.1504 - val_f1-score: 0.8967 - val_precision: 0.9179 - val_recall: 0.8791 - lr: 1.0000e-04
# Epoch 43/100
# 45/45 [==============================] - 409s 9s/step - loss: 0.7874 - iou_score: 0.1857 - f1-score: 0.9258 - precision: 0.9453 - recall: 0.9094 - val_loss: 0.8137 - val_iou_score: 0.1500 - val_f1-score: 0.8969 - val_precision: 0.9218 - val_recall: 0.8771 - lr: 1.0000e-04
# Epoch 44/100
# 45/45 [==============================] - 405s 9s/step - loss: 0.7869 - iou_score: 0.1865 - f1-score: 0.9267 - precision: 0.9470 - recall: 0.9096 - val_loss: 0.8128 - val_iou_score: 0.1514 - val_f1-score: 0.8977 - val_precision: 0.9187 - val_recall: 0.8806 - lr: 1.0000e-04
# Epoch 45/100
# 45/45 [==============================] - 403s 9s/step - loss: 0.7870 - iou_score: 0.1864 - f1-score: 0.9265 - precision: 0.9467 - recall: 0.9096 - val_loss: 0.8132 - val_iou_score: 0.1504 - val_f1-score: 0.8968 - val_precision: 0.9158 - val_recall: 0.8816 - lr: 1.0000e-04
# Epoch 46/100
# 45/45 [==============================] - 404s 9s/step - loss: 0.7864 - iou_score: 0.1872 - f1-score: 0.9271 - precision: 0.9468 - recall: 0.9105 - val_loss: 0.8128 - val_iou_score: 0.1513 - val_f1-score: 0.8976 - val_precision: 0.9186 - val_recall: 0.8807 - lr: 1.0000e-04
# Epoch 47/100
# 45/45 [==============================] - 402s 9s/step - loss: 0.7862 - iou_score: 0.1875 - f1-score: 0.9275 - precision: 0.9473 - recall: 0.9108 - val_loss: 0.8133 - val_iou_score: 0.1504 - val_f1-score: 0.8972 - val_precision: 0.9216 - val_recall: 0.8774 - lr: 1.0000e-04
# Epoch 48/100
# 45/45 [==============================] - 402s 9s/step - loss: 0.7861 - iou_score: 0.1878 - f1-score: 0.9279 - precision: 0.9479 - recall: 0.9110 - val_loss: 0.8126 - val_iou_score: 0.1512 - val_f1-score: 0.8977 - val_precision: 0.9181 - val_recall: 0.8808 - lr: 1.0000e-04
# Epoch 49/100
# 45/45 [==============================] - 403s 9s/step - loss: 0.7858 - iou_score: 0.1883 - f1-score: 0.9281 - precision: 0.9481 - recall: 0.9113 - val_loss: 0.8130 - val_iou_score: 0.1509 - val_f1-score: 0.8971 - val_precision: 0.9237 - val_recall: 0.8753 - lr: 1.0000e-04
# Epoch 50/100
# 45/45 [==============================] - 408s 9s/step - loss: 0.7856 - iou_score: 0.1887 - f1-score: 0.9283 - precision: 0.9483 - recall: 0.9118 - val_loss: 0.8127 - val_iou_score: 0.1511 - val_f1-score: 0.8974 - val_precision: 0.9192 - val_recall: 0.8793 - lr: 1.0000e-04
# Epoch 51/100
# 45/45 [==============================] - 411s 9s/step - loss: 0.7852 - iou_score: 0.1890 - f1-score: 0.9288 - precision: 0.9487 - recall: 0.9119 - val_loss: 0.8128 - val_iou_score: 0.1510 - val_f1-score: 0.8974 - val_precision: 0.9194 - val_recall: 0.8791 - lr: 1.0000e-04
# Epoch 52/100
# 45/45 [==============================] - 406s 9s/step - loss: 0.7853 - iou_score: 0.1890 - f1-score: 0.9288 - precision: 0.9489 - recall: 0.9119 - val_loss: 0.8131 - val_iou_score: 0.1507 - val_f1-score: 0.8974 - val_precision: 0.9213 - val_recall: 0.8781 - lr: 1.0000e-04
# Epoch 53/100
# 45/45 [==============================] - 407s 9s/step - loss: 0.7848 - iou_score: 0.1897 - f1-score: 0.9293 - precision: 0.9495 - recall: 0.9121 - val_loss: 0.8131 - val_iou_score: 0.1505 - val_f1-score: 0.8968 - val_precision: 0.9202 - val_recall: 0.8781 - lr: 1.0000e-04
# Epoch 54/100
# 45/45 [==============================] - 406s 9s/step - loss: 0.7845 - iou_score: 0.1901 - f1-score: 0.9298 - precision: 0.9494 - recall: 0.9133 - val_loss: 0.8128 - val_iou_score: 0.1512 - val_f1-score: 0.8978 - val_precision: 0.9225 - val_recall: 0.8775 - lr: 1.0000e-04
# Epoch 55/100
# 45/45 [==============================] - 408s 9s/step - loss: 0.7847 - iou_score: 0.1899 - f1-score: 0.9296 - precision: 0.9500 - recall: 0.9125 - val_loss: 0.8129 - val_iou_score: 0.1508 - val_f1-score: 0.8974 - val_precision: 0.9190 - val_recall: 0.8796 - lr: 1.0000e-04
# Epoch 56/100
# 45/45 [==============================] - 408s 9s/step - loss: 0.7848 - iou_score: 0.1895 - f1-score: 0.9294 - precision: 0.9493 - recall: 0.9127 - val_loss: 0.8136 - val_iou_score: 0.1498 - val_f1-score: 0.8966 - val_precision: 0.9209 - val_recall: 0.8774 - lr: 1.0000e-04
# Epoch 57/100
# 45/45 [==============================] - 404s 9s/step - loss: 0.7844 - iou_score: 0.1904 - f1-score: 0.9301 - precision: 0.9500 - recall: 0.9133 - val_loss: 0.8140 - val_iou_score: 0.1496 - val_f1-score: 0.8964 - val_precision: 0.9239 - val_recall: 0.8744 - lr: 1.0000e-04
# Epoch 58/100
# 45/45 [==============================] - 403s 9s/step - loss: 0.7842 - iou_score: 0.1906 - f1-score: 0.9304 - precision: 0.9504 - recall: 0.9135 - val_loss: 0.8131 - val_iou_score: 0.1506 - val_f1-score: 0.8973 - val_precision: 0.9196 - val_recall: 0.8792 - lr: 1.0000e-04
# Epoch 59/100
# 45/45 [==============================] - 405s 9s/step - loss: 0.7838 - iou_score: 0.1915 - f1-score: 0.9312 - precision: 0.9512 - recall: 0.9144 - val_loss: 0.8128 - val_iou_score: 0.1509 - val_f1-score: 0.8978 - val_precision: 0.9206 - val_recall: 0.8793 - lr: 1.0000e-05
# Epoch 60/100
# 45/45 [==============================] - 406s 9s/step - loss: 0.7834 - iou_score: 0.1919 - f1-score: 0.9316 - precision: 0.9514 - recall: 0.9148 - val_loss: 0.8128 - val_iou_score: 0.1511 - val_f1-score: 0.8979 - val_precision: 0.9214 - val_recall: 0.8786 - lr: 1.0000e-05
# Epoch 61/100
# 45/45 [==============================] - 409s 9s/step - loss: 0.7838 - iou_score: 0.1914 - f1-score: 0.9312 - precision: 0.9514 - recall: 0.9142 - val_loss: 0.8127 - val_iou_score: 0.1511 - val_f1-score: 0.8979 - val_precision: 0.9217 - val_recall: 0.8785 - lr: 1.0000e-05
# Epoch 62/100
# 45/45 [==============================] - 404s 9s/step - loss: 0.7834 - iou_score: 0.1917 - f1-score: 0.9314 - precision: 0.9515 - recall: 0.9143 - val_loss: 0.8128 - val_iou_score: 0.1512 - val_f1-score: 0.8979 - val_precision: 0.9227 - val_recall: 0.8777 - lr: 1.0000e-05
# Epoch 63/100
# 45/45 [==============================] - 399s 9s/step - loss: 0.7832 - iou_score: 0.1923 - f1-score: 0.9319 - precision: 0.9520 - recall: 0.9148 - val_loss: 0.8127 - val_iou_score: 0.1511 - val_f1-score: 0.8978 - val_precision: 0.9217 - val_recall: 0.8783 - lr: 1.0000e-05

# %%
model_in_mem.save('psp_softmax_1500_resnet50.hdf5')
from google.colab import files
files.download('psp_softmax_1500_resnet50.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
# model = load_model('psp_softmax_1500_resnet50.hdf5', compile=False)
model = model_in_mem

# IoU
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 11s 2s/step
# Mean IoU = 0.8294424
# [[1.6151735e+07 3.8190000e+04 1.3555000e+05 4.6000000e+01]
#  [3.5288000e+04 4.6659600e+05 2.2241000e+04 1.8620000e+03]
#  [1.3166900e+05 1.4527000e+04 6.5809720e+06 3.1200000e+02]
#  [7.4600000e+02 2.4950000e+03 1.3390000e+03 9.3920000e+03]]
# IoU for class1 is:  0.9792952
# IoU for class2 is:  0.8028163
# IoU for class3 is:  0.9556185
# IoU for class4 is:  0.5800395

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, vmin=0, vmax=3, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 89ms/step
