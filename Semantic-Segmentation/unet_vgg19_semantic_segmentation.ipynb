# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.0 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/train_test_data"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'vgg19'
preprocess_input = sm.get_preprocessing(BACKBONE)

# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
# model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=15)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=4,
        epochs=200,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 2s 0us/step
# Epoch 1/200
# 359/359 [==============================] - 54s 107ms/step - loss: 0.9674 - iou_score: 0.0024 - f1-score: 0.5391 - precision: 0.8458 - recall: 0.5290 - val_loss: 0.9868 - val_iou_score: 0.0035 - val_f1-score: 0.5936 - val_precision: 0.8516 - val_recall: 0.5898 - lr: 0.0010
# Epoch 2/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.9231 - iou_score: 0.0451 - f1-score: 0.6738 - precision: 0.8332 - recall: 0.6551 - val_loss: 0.9186 - val_iou_score: 0.0810 - val_f1-score: 0.7293 - val_precision: 0.8633 - val_recall: 0.6759 - lr: 0.0010
# Epoch 3/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8984 - iou_score: 0.0957 - f1-score: 0.7565 - precision: 0.7960 - recall: 0.7379 - val_loss: 0.9005 - val_iou_score: 0.0901 - val_f1-score: 0.7168 - val_precision: 0.8685 - val_recall: 0.6704 - lr: 0.0010
# Epoch 4/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8754 - iou_score: 0.1005 - f1-score: 0.7672 - precision: 0.8051 - recall: 0.7493 - val_loss: 0.8579 - val_iou_score: 0.1070 - val_f1-score: 0.7734 - val_precision: 0.8263 - val_recall: 0.7426 - lr: 0.0010
# Epoch 5/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8624 - iou_score: 0.1035 - f1-score: 0.7717 - precision: 0.8107 - recall: 0.7528 - val_loss: 0.8589 - val_iou_score: 0.1052 - val_f1-score: 0.7729 - val_precision: 0.8161 - val_recall: 0.7487 - lr: 0.0010
# Epoch 6/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8537 - iou_score: 0.1115 - f1-score: 0.7904 - precision: 0.8275 - recall: 0.7711 - val_loss: 0.8537 - val_iou_score: 0.1111 - val_f1-score: 0.7898 - val_precision: 0.8651 - val_recall: 0.7561 - lr: 0.0010
# Epoch 7/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8496 - iou_score: 0.1150 - f1-score: 0.7938 - precision: 0.8298 - recall: 0.7749 - val_loss: 0.8504 - val_iou_score: 0.1143 - val_f1-score: 0.7842 - val_precision: 0.7734 - val_recall: 0.8056 - lr: 0.0010
# Epoch 8/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8422 - iou_score: 0.1225 - f1-score: 0.8098 - precision: 0.8421 - recall: 0.7916 - val_loss: 0.8393 - val_iou_score: 0.1240 - val_f1-score: 0.8059 - val_precision: 0.8758 - val_recall: 0.7656 - lr: 0.0010
# Epoch 9/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8390 - iou_score: 0.1252 - f1-score: 0.8173 - precision: 0.8499 - recall: 0.7977 - val_loss: 0.8602 - val_iou_score: 0.1058 - val_f1-score: 0.7409 - val_precision: 0.8050 - val_recall: 0.7485 - lr: 0.0010
# Epoch 10/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8381 - iou_score: 0.1268 - f1-score: 0.8169 - precision: 0.8489 - recall: 0.7979 - val_loss: 0.8326 - val_iou_score: 0.1309 - val_f1-score: 0.8255 - val_precision: 0.8742 - val_recall: 0.7939 - lr: 0.0010
# Epoch 11/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8390 - iou_score: 0.1262 - f1-score: 0.8126 - precision: 0.8463 - recall: 0.7936 - val_loss: 0.8398 - val_iou_score: 0.1238 - val_f1-score: 0.7994 - val_precision: 0.8242 - val_recall: 0.7942 - lr: 0.0010
# Epoch 12/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8332 - iou_score: 0.1311 - f1-score: 0.8276 - precision: 0.8561 - recall: 0.8114 - val_loss: 0.8426 - val_iou_score: 0.1208 - val_f1-score: 0.7968 - val_precision: 0.8810 - val_recall: 0.7475 - lr: 0.0010
# Epoch 13/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8316 - iou_score: 0.1334 - f1-score: 0.8287 - precision: 0.8605 - recall: 0.8101 - val_loss: 0.8387 - val_iou_score: 0.1246 - val_f1-score: 0.8241 - val_precision: 0.8713 - val_recall: 0.7995 - lr: 0.0010
# Epoch 14/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8294 - iou_score: 0.1356 - f1-score: 0.8325 - precision: 0.8630 - recall: 0.8141 - val_loss: 0.8334 - val_iou_score: 0.1311 - val_f1-score: 0.8114 - val_precision: 0.8455 - val_recall: 0.7985 - lr: 0.0010
# Epoch 15/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8270 - iou_score: 0.1382 - f1-score: 0.8353 - precision: 0.8638 - recall: 0.8175 - val_loss: 0.8301 - val_iou_score: 0.1334 - val_f1-score: 0.8393 - val_precision: 0.8782 - val_recall: 0.8174 - lr: 0.0010
# Epoch 16/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8256 - iou_score: 0.1401 - f1-score: 0.8401 - precision: 0.8673 - recall: 0.8244 - val_loss: 0.8342 - val_iou_score: 0.1311 - val_f1-score: 0.8081 - val_precision: 0.8652 - val_recall: 0.7835 - lr: 0.0010
# Epoch 17/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8237 - iou_score: 0.1421 - f1-score: 0.8447 - precision: 0.8733 - recall: 0.8277 - val_loss: 0.8312 - val_iou_score: 0.1322 - val_f1-score: 0.8371 - val_precision: 0.8912 - val_recall: 0.8020 - lr: 0.0010
# Epoch 18/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8215 - iou_score: 0.1442 - f1-score: 0.8487 - precision: 0.8760 - recall: 0.8315 - val_loss: 0.8365 - val_iou_score: 0.1281 - val_f1-score: 0.7928 - val_precision: 0.8323 - val_recall: 0.7775 - lr: 0.0010
# Epoch 19/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8223 - iou_score: 0.1433 - f1-score: 0.8448 - precision: 0.8726 - recall: 0.8280 - val_loss: 0.8271 - val_iou_score: 0.1371 - val_f1-score: 0.8358 - val_precision: 0.8791 - val_recall: 0.8078 - lr: 0.0010
# Epoch 20/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8254 - iou_score: 0.1406 - f1-score: 0.8369 - precision: 0.8657 - recall: 0.8200 - val_loss: 0.8304 - val_iou_score: 0.1329 - val_f1-score: 0.8398 - val_precision: 0.8911 - val_recall: 0.8075 - lr: 0.0010
# Epoch 21/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8206 - iou_score: 0.1456 - f1-score: 0.8477 - precision: 0.8762 - recall: 0.8302 - val_loss: 0.8333 - val_iou_score: 0.1310 - val_f1-score: 0.8001 - val_precision: 0.8843 - val_recall: 0.7500 - lr: 0.0010
# Epoch 22/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8199 - iou_score: 0.1462 - f1-score: 0.8469 - precision: 0.8755 - recall: 0.8297 - val_loss: 0.8255 - val_iou_score: 0.1388 - val_f1-score: 0.8441 - val_precision: 0.8597 - val_recall: 0.8379 - lr: 0.0010
# Epoch 23/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8161 - iou_score: 0.1506 - f1-score: 0.8564 - precision: 0.8832 - recall: 0.8393 - val_loss: 0.8262 - val_iou_score: 0.1376 - val_f1-score: 0.8413 - val_precision: 0.8922 - val_recall: 0.8093 - lr: 0.0010
# Epoch 24/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8150 - iou_score: 0.1520 - f1-score: 0.8572 - precision: 0.8849 - recall: 0.8398 - val_loss: 0.8285 - val_iou_score: 0.1352 - val_f1-score: 0.8403 - val_precision: 0.8647 - val_recall: 0.8293 - lr: 0.0010
# Epoch 25/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8138 - iou_score: 0.1537 - f1-score: 0.8592 - precision: 0.8840 - recall: 0.8446 - val_loss: 0.8255 - val_iou_score: 0.1383 - val_f1-score: 0.8477 - val_precision: 0.8886 - val_recall: 0.8218 - lr: 0.0010
# Epoch 26/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8156 - iou_score: 0.1520 - f1-score: 0.8527 - precision: 0.8801 - recall: 0.8374 - val_loss: 0.8275 - val_iou_score: 0.1360 - val_f1-score: 0.8452 - val_precision: 0.8565 - val_recall: 0.8425 - lr: 0.0010
# Epoch 27/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8122 - iou_score: 0.1555 - f1-score: 0.8600 - precision: 0.8866 - recall: 0.8437 - val_loss: 0.8245 - val_iou_score: 0.1399 - val_f1-score: 0.8396 - val_precision: 0.8639 - val_recall: 0.8298 - lr: 0.0010
# Epoch 28/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8097 - iou_score: 0.1585 - f1-score: 0.8645 - precision: 0.8890 - recall: 0.8489 - val_loss: 0.8280 - val_iou_score: 0.1363 - val_f1-score: 0.8388 - val_precision: 0.9046 - val_recall: 0.7975 - lr: 0.0010
# Epoch 29/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.8106 - iou_score: 0.1580 - f1-score: 0.8621 - precision: 0.8885 - recall: 0.8457 - val_loss: 0.8302 - val_iou_score: 0.1346 - val_f1-score: 0.8229 - val_precision: 0.8635 - val_recall: 0.8022 - lr: 0.0010
# Epoch 30/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8100 - iou_score: 0.1583 - f1-score: 0.8631 - precision: 0.8899 - recall: 0.8462 - val_loss: 0.8236 - val_iou_score: 0.1408 - val_f1-score: 0.8485 - val_precision: 0.8598 - val_recall: 0.8473 - lr: 0.0010
# Epoch 31/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.8091 - iou_score: 0.1600 - f1-score: 0.8652 - precision: 0.8910 - recall: 0.8494 - val_loss: 0.8233 - val_iou_score: 0.1420 - val_f1-score: 0.8394 - val_precision: 0.8782 - val_recall: 0.8171 - lr: 0.0010
# Epoch 32/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.
200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7777 - iou_score: 0.2016 - f1-score: 0.9127 - precision: 0.9284 - recall: 0.9015 - val_loss: 0.8093 - val_iou_score: 0.1568 - val_f1-score: 0.8820 - val_precision: 0.9023 - val_recall: 0.8688 - lr: 0.0010
# Epoch 82/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7779 - iou_score: 0.2009 - f1-score: 0.9135 - precision: 0.9284 - recall: 0.9025 - val_loss: 0.8097 - val_iou_score: 0.1567 - val_f1-score: 0.8770 - val_precision: 0.8975 - val_recall: 0.8657 - lr: 0.0010
# Epoch 83/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7781 - iou_score: 0.2010 - f1-score: 0.9128 - precision: 0.9277 - recall: 0.9023 - val_loss: 0.8065 - val_iou_score: 0.1602 - val_f1-score: 0.8859 - val_precision: 0.9071 - val_recall: 0.8724 - lr: 0.0010
# Epoch 84/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7777 - iou_score: 0.2015 - f1-score: 0.9149 - precision: 0.9303 - recall: 0.9044 - val_loss: 0.8085 - val_iou_score: 0.1576 - val_f1-score: 0.8843 - val_precision: 0.9157 - val_recall: 0.8631 - lr: 0.0010
# Epoch 85/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7765 - iou_score: 0.2030 - f1-score: 0.9176 - precision: 0.9330 - recall: 0.9065 - val_loss: 0.8074 - val_iou_score: 0.1589 - val_f1-score: 0.8869 - val_precision: 0.9227 - val_recall: 0.8619 - lr: 0.0010
# Epoch 86/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7766 - iou_score: 0.2031 - f1-score: 0.9177 - precision: 0.9317 - recall: 0.9078 - val_loss: 0.8081 - val_iou_score: 0.1586 - val_f1-score: 0.8841 - val_precision: 0.9043 - val_recall: 0.8743 - lr: 0.0010
# Epoch 87/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7769 - iou_score: 0.2026 - f1-score: 0.9169 - precision: 0.9302 - recall: 0.9078 - val_loss: 0.8065 - val_iou_score: 0.1604 - val_f1-score: 0.8854 - val_precision: 0.9030 - val_recall: 0.8763 - lr: 0.0010
# Epoch 88/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7771 - iou_score: 0.2025 - f1-score: 0.9151 - precision: 0.9300 - recall: 0.9043 - val_loss: 0.8105 - val_iou_score: 0.1555 - val_f1-score: 0.8791 - val_precision: 0.9034 - val_recall: 0.8656 - lr: 0.0010
# Epoch 89/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7768 - iou_score: 0.2031 - f1-score: 0.9158 - precision: 0.9312 - recall: 0.9049 - val_loss: 0.8159 - val_iou_score: 0.1504 - val_f1-score: 0.8585 - val_precision: 0.9203 - val_recall: 0.8180 - lr: 0.0010
# Epoch 90/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7766 - iou_score: 0.2031 - f1-score: 0.9169 - precision: 0.9322 - recall: 0.9063 - val_loss: 0.8067 - val_iou_score: 0.1598 - val_f1-score: 0.8877 - val_precision: 0.9087 - val_recall: 0.8756 - lr: 0.0010
# Epoch 91/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7753 - iou_score: 0.2047 - f1-score: 0.9210 - precision: 0.9349 - recall: 0.9110 - val_loss: 0.8074 - val_iou_score: 0.1589 - val_f1-score: 0.8867 - val_precision: 0.9166 - val_recall: 0.8663 - lr: 0.0010
# Epoch 92/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7743 - iou_score: 0.2063 - f1-score: 0.9225 - precision: 0.9367 - recall: 0.9121 - val_loss: 0.8098 - val_iou_score: 0.1558 - val_f1-score: 0.8864 - val_precision: 0.9209 - val_recall: 0.8645 - lr: 0.0010
# Epoch 93/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7751 - iou_score: 0.2052 - f1-score: 0.9191 - precision: 0.9334 - recall: 0.9087 - val_loss: 0.8090 - val_iou_score: 0.1572 - val_f1-score: 0.8816 - val_precision: 0.9021 - val_recall: 0.8692 - lr: 0.0010
# Epoch 94/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7725 - iou_score: 0.2094 - f1-score: 0.9227 - precision: 0.9370 - recall: 0.9121 - val_loss: 0.8053 - val_iou_score: 0.1618 - val_f1-score: 0.8914 - val_precision: 0.9194 - val_recall: 0.8736 - lr: 1.0000e-04
# Epoch 95/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7702 - iou_score: 0.2130 - f1-score: 0.9275 - precision: 0.9424 - recall: 0.9165 - val_loss: 0.8049 - val_iou_score: 0.1621 - val_f1-score: 0.8930 - val_precision: 0.9204 - val_recall: 0.8758 - lr: 1.0000e-04
# Epoch 96/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7690 - iou_score: 0.2150 - f1-score: 0.9302 - precision: 0.9442 - recall: 0.9199 - val_loss: 0.8045 - val_iou_score: 0.1623 - val_f1-score: 0.8942 - val_precision: 0.9246 - val_recall: 0.8741 - lr: 1.0000e-04
# Epoch 97/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7686 - iou_score: 0.2157 - f1-score: 0.9313 - precision: 0.9462 - recall: 0.9202 - val_loss: 0.8044 - val_iou_score: 0.1627 - val_f1-score: 0.8950 - val_precision: 0.9269 - val_recall: 0.8737 - lr: 1.0000e-04
# Epoch 98/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7679 - iou_score: 0.2166 - f1-score: 0.9324 - precision: 0.9469 - recall: 0.9215 - val_loss: 0.8041 - val_iou_score: 0.1628 - val_f1-score: 0.8958 - val_precision: 0.9275 - val_recall: 0.8745 - lr: 1.0000e-04
# Epoch 99/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7674 - iou_score: 0.2175 - f1-score: 0.9337 - precision: 0.9483 - recall: 0.9226 - val_loss: 0.8039 - val_iou_score: 0.1632 - val_f1-score: 0.8966 - val_precision: 0.9225 - val_recall: 0.8805 - lr: 1.0000e-04
# Epoch 100/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7667 - iou_score: 0.2184 - f1-score: 0.9347 - precision: 0.9489 - recall: 0.9239 - val_loss: 0.8035 - val_iou_score: 0.1635 - val_f1-score: 0.8972 - val_precision: 0.9258 - val_recall: 0.8783 - lr: 1.0000e-04
# Epoch 101/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7666 - iou_score: 0.2189 - f1-score: 0.9348 - precision: 0.9490 - recall: 0.9242 - val_loss: 0.8046 - val_iou_score: 0.1622 - val_f1-score: 0.8961 - val_precision: 0.9271 - val_recall: 0.8759 - lr: 1.0000e-04
# Epoch 102/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7664 - iou_score: 0.2193 - f1-score: 0.9352 - precision: 0.9494 - recall: 0.9248 - val_loss: 0.8041 - val_iou_score: 0.1630 - val_f1-score: 0.8971 - val_precision: 0.9299 - val_recall: 0.8751 - lr: 1.0000e-04
# Epoch 103/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7662 - iou_score: 0.2195 - f1-score: 0.9356 - precision: 0.9504 - recall: 0.9245 - val_loss: 0.8035 - val_iou_score: 0.1636 - val_f1-score: 0.8976 - val_precision: 0.9288 - val_recall: 0.8764 - lr: 1.0000e-04
# Epoch 104/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7658 - iou_score: 0.2201 - f1-score: 0.9367 - precision: 0.9511 - recall: 0.9256 - val_loss: 0.8036 - val_iou_score: 0.1636 - val_f1-score: 0.8977 - val_precision: 0.9292 - val_recall: 0.8768 - lr: 1.0000e-04
# Epoch 105/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7658 - iou_score: 0.2203 - f1-score: 0.9369 - precision: 0.9518 - recall: 0.9259 - val_loss: 0.8032 - val_iou_score: 0.1641 - val_f1-score: 0.8985 - val_precision: 0.9281 - val_recall: 0.8787 - lr: 1.0000e-04
# Epoch 106/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7653 - iou_score: 0.2209 - f1-score: 0.9377 - precision: 0.9519 - recall: 0.9268 - val_loss: 0.8032 - val_iou_score: 0.1641 - val_f1-score: 0.8987 - val_precision: 0.9295 - val_recall: 0.8780 - lr: 1.0000e-04
# Epoch 107/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7653 - iou_score: 0.2212 - f1-score: 0.9377 - precision: 0.9520 - recall: 0.9270 - val_loss: 0.8033 - val_iou_score: 0.1638 - val_f1-score: 0.8987 - val_precision: 0.9291 - val_recall: 0.8783 - lr: 1.0000e-04
# Epoch 108/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7656 - iou_score: 0.2210 - f1-score: 0.9374 - precision: 0.9524 - recall: 0.9270 - val_loss: 0.8030 - val_iou_score: 0.1643 - val_f1-score: 0.8994 - val_precision: 0.9292 - val_recall: 0.8796 - lr: 1.0000e-04
# Epoch 109/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7648 - iou_score: 0.2217 - f1-score: 0.9387 - precision: 0.9529 - recall: 0.9280 - val_loss: 0.8029 - val_iou_score: 0.1643 - val_f1-score: 0.8992 - val_precision: 0.9296 - val_recall: 0.8787 - lr: 1.0000e-04
# Epoch 110/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7643 - iou_score: 0.2223 - f1-score: 0.9391 - precision: 0.9527 - recall: 0.9288 - val_loss: 0.8029 - val_iou_score: 0.1643 - val_f1-score: 0.8996 - val_precision: 0.9268 - val_recall: 0.8822 - lr: 1.0000e-04
# Epoch 111/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7647 - iou_score: 0.2219 - f1-score: 0.9391 - precision: 0.9533 - recall: 0.9285 - val_loss: 0.8027 - val_iou_score: 0.1646 - val_f1-score: 0.9001 - val_precision: 0.9277 - val_recall: 0.8823 - lr: 1.0000e-04
# Epoch 112/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7644 - iou_score: 0.2225 - f1-score: 0.9397 - precision: 0.9534 - recall: 0.9295 - val_loss: 0.8027 - val_iou_score: 0.1646 - val_f1-score: 0.9004 - val_precision: 0.9283 - val_recall: 0.8819 - lr: 1.0000e-04
# Epoch 113/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7642 - iou_score: 0.2224 - f1-score: 0.9400 - precision: 0.9542 - recall: 0.9290 - val_loss: 0.8029 - val_iou_score: 0.1643 - val_f1-score: 0.9002 - val_precision: 0.9290 - val_recall: 0.8811 - lr: 1.0000e-04
# Epoch 114/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7644 - iou_score: 0.2226 - f1-score: 0.9398 - precision: 0.9539 - recall: 0.9295 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9004 - val_precision: 0.9291 - val_recall: 0.8809 - lr: 1.0000e-04
# Epoch 115/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7642 - iou_score: 0.2229 - f1-score: 0.9402 - precision: 0.9543 - recall: 0.9299 - val_loss: 0.8029 - val_iou_score: 0.1643 - val_f1-score: 0.9003 - val_precision: 0.9269 - val_recall: 0.8833 - lr: 1.0000e-04
# Epoch 116/200
# 359/359 [==============================] - 36s 100ms/step - loss: 0.7640 - iou_score: 0.2231 - f1-score: 0.9406 - precision: 0.9545 - recall: 0.9301 - val_loss: 0.8029 - val_iou_score: 0.1644 - val_f1-score: 0.9005 - val_precision: 0.9301 - val_recall: 0.8810 - lr: 1.0000e-04
# Epoch 117/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7638 - iou_score: 0.2232 - f1-score: 0.9410 - precision: 0.9547 - recall: 0.9307 - val_loss: 0.8032 - val_iou_score: 0.1641 - val_f1-score: 0.9002 - val_precision: 0.9313 - val_recall: 0.8795 - lr: 1.0000e-04
# Epoch 118/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7640 - iou_score: 0.2231 - f1-score: 0.9410 - precision: 0.9551 - recall: 0.9305 - val_loss: 0.8023 - val_iou_score: 0.1651 - val_f1-score: 0.9014 - val_precision: 0.9281 - val_recall: 0.8841 - lr: 1.0000e-04
# Epoch 119/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7638 - iou_score: 0.2233 - f1-score: 0.9413 - precision: 0.9551 - recall: 0.9310 - val_loss: 0.8024 - val_iou_score: 0.1650 - val_f1-score: 0.9017 - val_precision: 0.9298 - val_recall: 0.8830 - lr: 1.0000e-04
# Epoch 120/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7633 - iou_score: 0.2239 - f1-score: 0.9420 - precision: 0.9555 - recall: 0.9317 - val_loss: 0.8025 - val_iou_score: 0.1649 - val_f1-score: 0.9015 - val_precision: 0.9264 - val_recall: 0.8858 - lr: 1.0000e-04
# Epoch 121/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7633 - iou_score: 0.2239 - f1-score: 0.9421 - precision: 0.9558 - recall: 0.9317 - val_loss: 0.8031 - val_iou_score: 0.1640 - val_f1-score: 0.9008 - val_precision: 0.9317 - val_recall: 0.8802 - lr: 1.0000e-04
# Epoch 122/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7636 - iou_score: 0.2238 - f1-score: 0.9419 - precision: 0.9558 - recall: 0.9318 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9014 - val_precision: 0.9288 - val_recall: 0.8834 - lr: 1.0000e-04
# Epoch 123/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7632 - iou_score: 0.2241 - f1-score: 0.9426 - precision: 0.9562 - recall: 0.9323 - val_loss: 0.8022 - val_iou_score: 0.1651 - val_f1-score: 0.9021 - val_precision: 0.9283 - val_recall: 0.8851 - lr: 1.0000e-04
# Epoch 124/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7634 - iou_score: 0.2242 - f1-score: 0.9424 - precision: 0.9562 - recall: 0.9322 - val_loss: 0.8025 - val_iou_score: 0.1650 - val_f1-score: 0.9017 - val_precision: 0.9310 - val_recall: 0.8824 - lr: 1.0000e-04
# Epoch 125/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7636 - iou_score: 0.2237 - f1-score: 0.9423 - precision: 0.9566 - recall: 0.9317 - val_loss: 0.8023 - val_iou_score: 0.1651 - val_f1-score: 0.9021 - val_precision: 0.9305 - val_recall: 0.8835 - lr: 1.0000e-05
# Epoch 126/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2249 - f1-score: 0.9434 - precision: 0.9568 - recall: 0.9333 - val_loss: 0.8024 - val_iou_score: 0.1649 - val_f1-score: 0.9020 - val_precision: 0.9302 - val_recall: 0.8837 - lr: 1.0000e-05
# Epoch 127/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7632 - iou_score: 0.2243 - f1-score: 0.9429 - precision: 0.9569 - recall: 0.9327 - val_loss: 0.8023 - val_iou_score: 0.1649 - val_f1-score: 0.9020 - val_precision: 0.9306 - val_recall: 0.8832 - lr: 1.0000e-05
# Epoch 128/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2249 - f1-score: 0.9432 - precision: 0.9569 - recall: 0.9329 - val_loss: 0.8024 - val_iou_score: 0.1650 - val_f1-score: 0.9021 - val_precision: 0.9305 - val_recall: 0.8835 - lr: 1.0000e-05
# Epoch 129/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7631 - iou_score: 0.2244 - f1-score: 0.9429 - precision: 0.9568 - recall: 0.9326 - val_loss: 0.8023 - val_iou_score: 0.1652 - val_f1-score: 0.9022 - val_precision: 0.9307 - val_recall: 0.8834 - lr: 1.0000e-05
# Epoch 130/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7629 - iou_score: 0.2249 - f1-score: 0.9432 - precision: 0.9571 - recall: 0.9330 - val_loss: 0.8021 - val_iou_score: 0.1652 - val_f1-score: 0.9023 - val_precision: 0.9304 - val_recall: 0.8838 - lr: 1.0000e-05
# Epoch 131/200
# 359/359 [==============================] - 36s 102ms/step - loss: 0.7631 - iou_score: 0.2246 - f1-score: 0.9430 - precision: 0.9571 - recall: 0.9326 - val_loss: 0.8024 - val_iou_score: 0.1649 - val_f1-score: 0.9021 - val_precision: 0.9304 - val_recall: 0.8837 - lr: 1.0000e-05
# Epoch 132/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2249 - f1-score: 0.9435 - precision: 0.9572 - recall: 0.9332 - val_loss: 0.8022 - val_iou_score: 0.1652 - val_f1-score: 0.9023 - val_precision: 0.9302 - val_recall: 0.8840 - lr: 1.0000e-05
# Epoch 133/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2250 - f1-score: 0.9435 - precision: 0.9573 - recall: 0.9332 - val_loss: 0.8022 - val_iou_score: 0.1651 - val_f1-score: 0.9023 - val_precision: 0.9300 - val_recall: 0.8842 - lr: 1.0000e-05
# Epoch 134/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7626 - iou_score: 0.2250 - f1-score: 0.9437 - precision: 0.9573 - recall: 0.9333 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9023 - val_precision: 0.9304 - val_recall: 0.8839 - lr: 1.0000e-05
# Epoch 135/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2251 - f1-score: 0.9435 - precision: 0.9576 - recall: 0.9332 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9022 - val_precision: 0.9297 - val_recall: 0.8846 - lr: 1.0000e-05
# Epoch 136/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7621 - iou_score: 0.2259 - f1-score: 0.9443 - precision: 0.9573 - recall: 0.9344 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9022 - val_precision: 0.9304 - val_recall: 0.8839 - lr: 1.0000e-05
# Epoch 137/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7625 - iou_score: 0.2253 - f1-score: 0.9434 - precision: 0.9571 - recall: 0.9333 - val_loss: 0.8023 - val_iou_score: 0.1651 - val_f1-score: 0.9023 - val_precision: 0.9309 - val_recall: 0.8836 - lr: 1.0000e-05
# Epoch 138/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2249 - f1-score: 0.9434 - precision: 0.9573 - recall: 0.9330 - val_loss: 0.8023 - val_iou_score: 0.1651 - val_f1-score: 0.9024 - val_precision: 0.9305 - val_recall: 0.8840 - lr: 1.0000e-05
# Epoch 139/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7629 - iou_score: 0.2250 - f1-score: 0.9433 - precision: 0.9571 - recall: 0.9333 - val_loss: 0.8023 - val_iou_score: 0.1651 - val_f1-score: 0.9023 - val_precision: 0.9306 - val_recall: 0.8838 - lr: 1.0000e-05
# Epoch 140/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2252 - f1-score: 0.9436 - precision: 0.9575 - recall: 0.9336 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9023 - val_precision: 0.9301 - val_recall: 0.8842 - lr: 1.0000e-05
# Epoch 141/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7621 - iou_score: 0.2259 - f1-score: 0.9443 - precision: 0.9575 - recall: 0.9342 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9023 - val_precision: 0.9312 - val_recall: 0.8834 - lr: 1.0000e-05
# Epoch 142/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7629 - iou_score: 0.2249 - f1-score: 0.9435 - precision: 0.9573 - recall: 0.9334 - val_loss: 0.8023 - val_iou_score: 0.1650 - val_f1-score: 0.9024 - val_precision: 0.9310 - val_recall: 0.8835 - lr: 1.0000e-05
# Epoch 143/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7628 - iou_score: 0.2251 - f1-score: 0.9437 - precision: 0.9577 - recall: 0.9335 - val_loss: 0.8024 - val_iou_score: 0.1648 - val_f1-score: 0.9023 - val_precision: 0.9303 - val_recall: 0.8841 - lr: 1.0000e-05
# Epoch 144/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7622 - iou_score: 0.2258 - f1-score: 0.9441 - precision: 0.9572 - recall: 0.9343 - val_loss: 0.8023 - val_iou_score: 0.1648 - val_f1-score: 0.9022 - val_precision: 0.9298 - val_recall: 0.8844 - lr: 1.0000e-05
# Epoch 145/200
# 359/359 [==============================] - 36s 101ms/step - loss: 0.7625 - iou_score: 0.2254 - f1-score: 0.9438 - precision: 0.9575 - recall: 0.9338 - val_loss: 0.8024 - val_iou_score: 0.1648 - val_f1-score: 0.9023 - val_precision: 0.9304 - val_recall: 0.8840 - lr: 1.0000e-05

# %%
model_in_mem.save('unet_softmax_1500_vgg19.hdf5')
from google.colab import files
files.download('unet_softmax_1500_vgg19.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
# model = load_model('psp_softmax_1500_resnet50.hdf5', compile=False)
model = model_in_mem

# IoU
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 6s 137ms/step
# Mean IoU = 0.83419704
# [[1.6107296e+07 3.9149000e+04 2.0955600e+05 4.1000000e+01]
#  [3.3038000e+04 4.6770800e+05 2.0714000e+04 1.3460000e+03]
#  [2.3572500e+05 1.7886000e+04 6.4464280e+06 9.0000000e+01]
#  [1.7200000e+02 2.9610000e+03 1.0270000e+03 9.8230000e+03]]
# IoU for class1 is:  0.9688612
# IoU for class2 is:  0.8025161
# IoU for class3 is:  0.9300291
# IoU for class4 is:  0.63538164

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
