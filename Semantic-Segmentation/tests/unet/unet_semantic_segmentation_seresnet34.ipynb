# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.3 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/train_test_data"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'seresnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
# model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=10)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=16,
        epochs=100,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/seresnet34_imagenet_1000_no_top.h5
# 86315168/86315168 [==============================] - 4s 0us/step
# Epoch 1/100
# 90/90 [==============================] - 88s 686ms/step - loss: 0.9631 - iou_score: 0.0364 - f1-score: 0.6306 - precision: 0.8058 - recall: 0.6354 - val_loss: 1.0462 - val_iou_score: 2.6307e-04 - val_f1-score: 0.2857 - val_precision: 0.7969 - val_recall: 0.3041 - lr: 0.0010
# Epoch 2/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.8516 - iou_score: 0.1113 - f1-score: 0.8132 - precision: 0.8413 - recall: 0.7940 - val_loss: 1.1567 - val_iou_score: 0.0269 - val_f1-score: 0.4865 - val_precision: 0.7775 - val_recall: 0.4680 - lr: 0.0010
# Epoch 3/100
# 90/90 [==============================] - 53s 589ms/step - loss: 0.8382 - iou_score: 0.1231 - f1-score: 0.8476 - precision: 0.8661 - recall: 0.8348 - val_loss: 0.8429 - val_iou_score: 0.1206 - val_f1-score: 0.8352 - val_precision: 0.8801 - val_recall: 0.8018 - lr: 0.0010
# Epoch 4/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.8300 - iou_score: 0.1312 - f1-score: 0.8646 - precision: 0.8817 - recall: 0.8526 - val_loss: 0.8303 - val_iou_score: 0.1308 - val_f1-score: 0.8644 - val_precision: 0.8789 - val_recall: 0.8525 - lr: 0.0010
# Epoch 5/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8269 - iou_score: 0.1344 - f1-score: 0.8702 - precision: 0.8868 - recall: 0.8584 - val_loss: 0.8368 - val_iou_score: 0.1233 - val_f1-score: 0.8598 - val_precision: 0.9029 - val_recall: 0.8313 - lr: 0.0010
# Epoch 6/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8235 - iou_score: 0.1379 - f1-score: 0.8767 - precision: 0.8924 - recall: 0.8651 - val_loss: 0.8423 - val_iou_score: 0.1175 - val_f1-score: 0.8498 - val_precision: 0.9192 - val_recall: 0.8069 - lr: 0.0010
# Epoch 7/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.8199 - iou_score: 0.1422 - f1-score: 0.8802 - precision: 0.8944 - recall: 0.8697 - val_loss: 0.8236 - val_iou_score: 0.1383 - val_f1-score: 0.8699 - val_precision: 0.8960 - val_recall: 0.8480 - lr: 0.0010
# Epoch 8/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8191 - iou_score: 0.1434 - f1-score: 0.8797 - precision: 0.8952 - recall: 0.8685 - val_loss: 0.8835 - val_iou_score: 0.1044 - val_f1-score: 0.7159 - val_precision: 0.7742 - val_recall: 0.7001 - lr: 0.0010
# Epoch 9/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8168 - iou_score: 0.1460 - f1-score: 0.8813 - precision: 0.8969 - recall: 0.8697 - val_loss: 0.8256 - val_iou_score: 0.1353 - val_f1-score: 0.8690 - val_precision: 0.8644 - val_recall: 0.8790 - lr: 0.0010
# Epoch 10/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8146 - iou_score: 0.1484 - f1-score: 0.8870 - precision: 0.9004 - recall: 0.8776 - val_loss: 0.8275 - val_iou_score: 0.1330 - val_f1-score: 0.8770 - val_precision: 0.9181 - val_recall: 0.8515 - lr: 0.0010
# Epoch 11/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8114 - iou_score: 0.1522 - f1-score: 0.8930 - precision: 0.9060 - recall: 0.8835 - val_loss: 0.8239 - val_iou_score: 0.1386 - val_f1-score: 0.8750 - val_precision: 0.9099 - val_recall: 0.8465 - lr: 0.0010
# Epoch 12/100
# 90/90 [==============================] - 53s 589ms/step - loss: 0.8100 - iou_score: 0.1537 - f1-score: 0.8931 - precision: 0.9041 - recall: 0.8852 - val_loss: 0.8331 - val_iou_score: 0.1378 - val_f1-score: 0.7663 - val_precision: 0.7433 - val_recall: 0.8592 - lr: 0.0010
# Epoch 13/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.8076 - iou_score: 0.1571 - f1-score: 0.8918 - precision: 0.9016 - recall: 0.8847 - val_loss: 0.8283 - val_iou_score: 0.1336 - val_f1-score: 0.8652 - val_precision: 0.8754 - val_recall: 0.8635 - lr: 0.0010
# Epoch 14/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.8053 - iou_score: 0.1598 - f1-score: 0.8954 - precision: 0.9042 - recall: 0.8891 - val_loss: 0.8192 - val_iou_score: 0.1427 - val_f1-score: 0.8773 - val_precision: 0.9049 - val_recall: 0.8536 - lr: 0.0010
# Epoch 15/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.8016 - iou_score: 0.1645 - f1-score: 0.9038 - precision: 0.9127 - recall: 0.8973 - val_loss: 0.8158 - val_iou_score: 0.1465 - val_f1-score: 0.8879 - val_precision: 0.8944 - val_recall: 0.8835 - lr: 0.0010
# Epoch 16/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7996 - iou_score: 0.1670 - f1-score: 0.9067 - precision: 0.9140 - recall: 0.9015 - val_loss: 0.8145 - val_iou_score: 0.1481 - val_f1-score: 0.8859 - val_precision: 0.9212 - val_recall: 0.8573 - lr: 0.0010
# Epoch 17/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7981 - iou_score: 0.1693 - f1-score: 0.9093 - precision: 0.9191 - recall: 0.9020 - val_loss: 0.8154 - val_iou_score: 0.1465 - val_f1-score: 0.8899 - val_precision: 0.9107 - val_recall: 0.8749 - lr: 0.0010
# Epoch 18/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7952 - iou_score: 0.1728 - f1-score: 0.9132 - precision: 0.9203 - recall: 0.9079 - val_loss: 0.8151 - val_iou_score: 0.1471 - val_f1-score: 0.8916 - val_precision: 0.9023 - val_recall: 0.8827 - lr: 0.0010
# Epoch 19/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7964 - iou_score: 0.1715 - f1-score: 0.9092 - precision: 0.9168 - recall: 0.9035 - val_loss: 0.8125 - val_iou_score: 0.1507 - val_f1-score: 0.8894 - val_precision: 0.9119 - val_recall: 0.8710 - lr: 0.0010
# Epoch 20/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7951 - iou_score: 0.1731 - f1-score: 0.9130 - precision: 0.9216 - recall: 0.9067 - val_loss: 0.8094 - val_iou_score: 0.1539 - val_f1-score: 0.8976 - val_precision: 0.9064 - val_recall: 0.8916 - lr: 0.0010
# Epoch 21/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7932 - iou_score: 0.1755 - f1-score: 0.9158 - precision: 0.9232 - recall: 0.9104 - val_loss: 0.8111 - val_iou_score: 0.1519 - val_f1-score: 0.8944 - val_precision: 0.9085 - val_recall: 0.8823 - lr: 0.0010
# Epoch 22/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7917 - iou_score: 0.1776 - f1-score: 0.9176 - precision: 0.9262 - recall: 0.9107 - val_loss: 0.8097 - val_iou_score: 0.1534 - val_f1-score: 0.8991 - val_precision: 0.9098 - val_recall: 0.8929 - lr: 0.0010
# Epoch 23/100
# 90/90 [==============================] - 53s 593ms/step - loss: 0.7915 - iou_score: 0.1779 - f1-score: 0.9187 - precision: 0.9265 - recall: 0.9130 - val_loss: 0.8089 - val_iou_score: 0.1546 - val_f1-score: 0.8998 - val_precision: 0.9099 - val_recall: 0.8910 - lr: 0.0010
# Epoch 24/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7894 - iou_score: 0.1809 - f1-score: 0.9213 - precision: 0.9297 - recall: 0.9147 - val_loss: 0.8099 - val_iou_score: 0.1533 - val_f1-score: 0.8961 - val_precision: 0.9265 - val_recall: 0.8709 - lr: 0.0010
# Epoch 25/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7895 - iou_score: 0.1806 - f1-score: 0.9202 - precision: 0.9276 - recall: 0.9142 - val_loss: 0.8098 - val_iou_score: 0.1536 - val_f1-score: 0.8970 - val_precision: 0.9092 - val_recall: 0.8872 - lr: 0.0010
# Epoch 26/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7881 - iou_score: 0.1828 - f1-score: 0.9226 - precision: 0.9291 - recall: 0.9176 - val_loss: 0.8089 - val_iou_score: 0.1544 - val_f1-score: 0.9021 - val_precision: 0.9241 - val_recall: 0.8855 - lr: 0.0010
# Epoch 27/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7881 - iou_score: 0.1826 - f1-score: 0.9227 - precision: 0.9309 - recall: 0.9160 - val_loss: 0.8086 - val_iou_score: 0.1548 - val_f1-score: 0.9024 - val_precision: 0.9217 - val_recall: 0.8879 - lr: 0.0010
# Epoch 28/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7880 - iou_score: 0.1828 - f1-score: 0.9226 - precision: 0.9311 - recall: 0.9158 - val_loss: 0.8076 - val_iou_score: 0.1560 - val_f1-score: 0.9022 - val_precision: 0.9300 - val_recall: 0.8801 - lr: 0.0010
# Epoch 29/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7872 - iou_score: 0.1840 - f1-score: 0.9226 - precision: 0.9301 - recall: 0.9169 - val_loss: 0.8091 - val_iou_score: 0.1542 - val_f1-score: 0.9013 - val_precision: 0.9049 - val_recall: 0.8986 - lr: 0.0010
# Epoch 30/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7860 - iou_score: 0.1857 - f1-score: 0.9244 - precision: 0.9323 - recall: 0.9183 - val_loss: 0.8090 - val_iou_score: 0.1549 - val_f1-score: 0.8976 - val_precision: 0.9011 - val_recall: 0.8999 - lr: 0.0010
# Epoch 31/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7867 - iou_score: 0.1847 - f1-score: 0.9241 - precision: 0.9305 - recall: 0.9192 - val_loss: 0.8094 - val_iou_score: 0.1539 - val_f1-score: 0.9007 - val_precision: 0.8981 - val_recall: 0.9051 - lr: 0.0010
# Epoch 32/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7851 - iou_score: 0.1870 - f1-score: 0.9256 - precision: 0.9335 - recall: 0.9193 - val_loss: 0.8098 - val_iou_score: 0.1532 - val_f1-score: 0.9004 - val_precision: 0.9229 - val_recall: 0.8858 - lr: 0.0010
# Epoch 33/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7844 - iou_score: 0.1879 - f1-score: 0.9264 - precision: 0.9334 - recall: 0.9211 - val_loss: 0.8073 - val_iou_score: 0.1567 - val_f1-score: 0.9030 - val_precision: 0.9083 - val_recall: 0.8984 - lr: 0.0010
# Epoch 34/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7834 - iou_score: 0.1896 - f1-score: 0.9282 - precision: 0.9358 - recall: 0.9222 - val_loss: 0.8067 - val_iou_score: 0.1574 - val_f1-score: 0.9039 - val_precision: 0.9119 - val_recall: 0.8985 - lr: 0.0010
# Epoch 35/100
# 90/90 [==============================] - 53s 593ms/step - loss: 0.7835 - iou_score: 0.1896 - f1-score: 0.9281 - precision: 0.9353 - recall: 0.9227 - val_loss: 0.8056 - val_iou_score: 0.1587 - val_f1-score: 0.9031 - val_precision: 0.9258 - val_recall: 0.8838 - lr: 0.0010
# Epoch 36/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7832 - iou_score: 0.1898 - f1-score: 0.9287 - precision: 0.9356 - recall: 0.9231 - val_loss: 0.8081 - val_iou_score: 0.1554 - val_f1-score: 0.9022 - val_precision: 0.9230 - val_recall: 0.8852 - lr: 0.0010
# Epoch 37/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7831 - iou_score: 0.1898 - f1-score: 0.9285 - precision: 0.9345 - recall: 0.9239 - val_loss: 0.8055 - val_iou_score: 0.1588 - val_f1-score: 0.9037 - val_precision: 0.9233 - val_recall: 0.8871 - lr: 0.0010
# Epoch 38/100
# 90/90 [==============================] - 53s 589ms/step - loss: 0.7828 - iou_score: 0.1904 - f1-score: 0.9293 - precision: 0.9365 - recall: 0.9237 - val_loss: 0.8068 - val_iou_score: 0.1571 - val_f1-score: 0.9037 - val_precision: 0.9296 - val_recall: 0.8829 - lr: 0.0010
# Epoch 39/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7820 - iou_score: 0.1915 - f1-score: 0.9302 - precision: 0.9360 - recall: 0.9257 - val_loss: 0.8065 - val_iou_score: 0.1575 - val_f1-score: 0.9041 - val_precision: 0.9118 - val_recall: 0.8988 - lr: 0.0010
# Epoch 40/100
# 90/90 [==============================] - 53s 593ms/step - loss: 0.7815 - iou_score: 0.1923 - f1-score: 0.9308 - precision: 0.9373 - recall: 0.9257 - val_loss: 0.8054 - val_iou_score: 0.1591 - val_f1-score: 0.9064 - val_precision: 0.9224 - val_recall: 0.8939 - lr: 0.0010
# Epoch 41/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7804 - iou_score: 0.1941 - f1-score: 0.9313 - precision: 0.9379 - recall: 0.9260 - val_loss: 0.8065 - val_iou_score: 0.1582 - val_f1-score: 0.9011 - val_precision: 0.9198 - val_recall: 0.8851 - lr: 0.0010
# Epoch 42/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7805 - iou_score: 0.1939 - f1-score: 0.9298 - precision: 0.9365 - recall: 0.9244 - val_loss: 0.8065 - val_iou_score: 0.1574 - val_f1-score: 0.9035 - val_precision: 0.9222 - val_recall: 0.8896 - lr: 0.0010
# Epoch 43/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7799 - iou_score: 0.1947 - f1-score: 0.9326 - precision: 0.9378 - recall: 0.9285 - val_loss: 0.8029 - val_iou_score: 0.1622 - val_f1-score: 0.9077 - val_precision: 0.9109 - val_recall: 0.9062 - lr: 0.0010
# Epoch 44/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7792 - iou_score: 0.1958 - f1-score: 0.9334 - precision: 0.9400 - recall: 0.9280 - val_loss: 0.8069 - val_iou_score: 0.1573 - val_f1-score: 0.9018 - val_precision: 0.8961 - val_recall: 0.9098 - lr: 0.0010
# Epoch 45/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7796 - iou_score: 0.1951 - f1-score: 0.9325 - precision: 0.9386 - recall: 0.9278 - val_loss: 0.8047 - val_iou_score: 0.1598 - val_f1-score: 0.9047 - val_precision: 0.9239 - val_recall: 0.8891 - lr: 0.0010
# Epoch 46/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7796 - iou_score: 0.1953 - f1-score: 0.9317 - precision: 0.9373 - recall: 0.9273 - val_loss: 0.8062 - val_iou_score: 0.1580 - val_f1-score: 0.9047 - val_precision: 0.9208 - val_recall: 0.8923 - lr: 0.0010
# Epoch 47/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7784 - iou_score: 0.1969 - f1-score: 0.9341 - precision: 0.9402 - recall: 0.9292 - val_loss: 0.8092 - val_iou_score: 0.1540 - val_f1-score: 0.9003 - val_precision: 0.9216 - val_recall: 0.8837 - lr: 0.0010
# Epoch 48/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7790 - iou_score: 0.1960 - f1-score: 0.9326 - precision: 0.9393 - recall: 0.9272 - val_loss: 0.8083 - val_iou_score: 0.1554 - val_f1-score: 0.9014 - val_precision: 0.9086 - val_recall: 0.8965 - lr: 0.0010
# Epoch 49/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7775 - iou_score: 0.1984 - f1-score: 0.9346 - precision: 0.9409 - recall: 0.9295 - val_loss: 0.8081 - val_iou_score: 0.1555 - val_f1-score: 0.9032 - val_precision: 0.9301 - val_recall: 0.8816 - lr: 0.0010
# Epoch 50/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7770 - iou_score: 0.1992 - f1-score: 0.9358 - precision: 0.9425 - recall: 0.9302 - val_loss: 0.8068 - val_iou_score: 0.1570 - val_f1-score: 0.9051 - val_precision: 0.9314 - val_recall: 0.8840 - lr: 0.0010
# Epoch 51/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7771 - iou_score: 0.1989 - f1-score: 0.9363 - precision: 0.9427 - recall: 0.9311 - val_loss: 0.8072 - val_iou_score: 0.1567 - val_f1-score: 0.9045 - val_precision: 0.9334 - val_recall: 0.8832 - lr: 0.0010
# Epoch 52/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7766 - iou_score: 0.1996 - f1-score: 0.9365 - precision: 0.9439 - recall: 0.9305 - val_loss: 0.8015 - val_iou_score: 0.1639 - val_f1-score: 0.9098 - val_precision: 0.9201 - val_recall: 0.9010 - lr: 0.0010
# Epoch 53/100
# 90/90 [==============================] - 53s 589ms/step - loss: 0.7760 - iou_score: 0.2007 - f1-score: 0.9376 - precision: 0.9435 - recall: 0.9330 - val_loss: 0.8038 - val_iou_score: 0.1610 - val_f1-score: 0.9082 - val_precision: 0.9253 - val_recall: 0.8940 - lr: 0.0010
# Epoch 54/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7777 - iou_score: 0.1982 - f1-score: 0.9346 - precision: 0.9426 - recall: 0.9281 - val_loss: 0.8084 - val_iou_score: 0.1554 - val_f1-score: 0.9027 - val_precision: 0.9209 - val_recall: 0.8898 - lr: 0.0010
# Epoch 55/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7757 - iou_score: 0.2011 - f1-score: 0.9373 - precision: 0.9434 - recall: 0.9322 - val_loss: 0.8023 - val_iou_score: 0.1632 - val_f1-score: 0.9090 - val_precision: 0.9165 - val_recall: 0.9042 - lr: 0.0010
# Epoch 56/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7764 - iou_score: 0.2000 - f1-score: 0.9365 - precision: 0.9429 - recall: 0.9312 - val_loss: 0.8035 - val_iou_score: 0.1614 - val_f1-score: 0.9073 - val_precision: 0.9198 - val_recall: 0.8981 - lr: 0.0010
# Epoch 57/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7751 - iou_score: 0.2020 - f1-score: 0.9383 - precision: 0.9454 - recall: 0.9325 - val_loss: 0.8018 - val_iou_score: 0.1636 - val_f1-score: 0.9092 - val_precision: 0.9163 - val_recall: 0.9044 - lr: 0.0010
# Epoch 58/100
# 90/90 [==============================] - 53s 591ms/step - loss: 0.7746 - iou_score: 0.2028 - f1-score: 0.9395 - precision: 0.9452 - recall: 0.9347 - val_loss: 0.8040 - val_iou_score: 0.1609 - val_f1-score: 0.9065 - val_precision: 0.9231 - val_recall: 0.8938 - lr: 0.0010
# Epoch 59/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7748 - iou_score: 0.2026 - f1-score: 0.9378 - precision: 0.9450 - recall: 0.9322 - val_loss: 0.8065 - val_iou_score: 0.1576 - val_f1-score: 0.9015 - val_precision: 0.9209 - val_recall: 0.8892 - lr: 0.0010
# Epoch 60/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7755 - iou_score: 0.2013 - f1-score: 0.9371 - precision: 0.9439 - recall: 0.9314 - val_loss: 0.8053 - val_iou_score: 0.1593 - val_f1-score: 0.9021 - val_precision: 0.9279 - val_recall: 0.8809 - lr: 0.0010
# Epoch 61/100
# 90/90 [==============================] - 53s 590ms/step - loss: 0.7760 - iou_score: 0.2008 - f1-score: 0.9350 - precision: 0.9413 - recall: 0.9302 - val_loss: 0.8047 - val_iou_score: 0.1606 - val_f1-score: 0.9004 - val_precision: 0.9239 - val_recall: 0.8801 - lr: 0.0010
# Epoch 62/100
# 90/90 [==============================] - 53s 592ms/step - loss: 0.7771 - iou_score: 0.1992 - f1-score: 0.9338 - precision: 0.9400 - recall: 0.9287 - val_loss: 0.8076 - val_iou_score: 0.1566 - val_f1-score: 0.8992 - val_precision: 0.9310 - val_recall: 0.8732 - lr: 0.0010

# %%
model_in_mem.save('unet_softmax_1500_seresnet34.hdf5')
from google.colab import files
files.download('unet_softmax_1500_seresnet34.hdf5')

# %%
files.download('unet_softmax_1500_seresnet34.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
# model = load_model('/content/psp_softmax_1500_vgg16.hdf5', compile=False)
model = model_in_mem

# IoU
X_test = preprocess_input(X_test)
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 10s 232ms/step
# Mean IoU = 0.8463744
# [[1.6219525e+07 3.4224000e+04 7.9277000e+04 2.1000000e+01]
#  [3.4121000e+04 4.6892900e+05 1.1760000e+04 2.0250000e+03]
#  [2.1634900e+05 1.6728000e+04 6.4961480e+06 3.3400000e+02]
#  [1.4800000e+02 2.5010000e+03 8.0800000e+02 1.0062000e+04]]
# IoU for class1 is:  0.97804224
# IoU for class2 is:  0.822267
# IoU for class3 is:  0.9523183
# IoU for class4 is:  0.63287

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, vmin=0, vmax=3, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
