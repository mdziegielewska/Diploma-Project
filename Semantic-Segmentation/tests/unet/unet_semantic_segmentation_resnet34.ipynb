# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.3 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/train_test_data"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
# model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=15)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=16,
        epochs=200,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85521592/85521592 [==============================] - 5s 0us/step
# Epoch 1/200
# 90/90 [==============================] - 81s 645ms/step - loss: 1.0035 - iou_score: 0.0037 - f1-score: 0.5896 - precision: 0.8786 - recall: 0.5775 - val_loss: 1.0052 - val_iou_score: 0.0034 - val_f1-score: 0.6214 - val_precision: 0.7019 - val_recall: 0.5842 - lr: 0.0010
# Epoch 2/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.9214 - iou_score: 0.0666 - f1-score: 0.7610 - precision: 0.8051 - recall: 0.7672 - val_loss: 1.2989 - val_iou_score: 0.0069 - val_f1-score: 0.4115 - val_precision: 0.4191 - val_recall: 0.6142 - lr: 0.0010
# Epoch 3/200
# 90/90 [==============================] - 49s 546ms/step - loss: 0.8540 - iou_score: 0.1080 - f1-score: 0.8161 - precision: 0.8473 - recall: 0.7934 - val_loss: 1.0383 - val_iou_score: 0.0640 - val_f1-score: 0.5875 - val_precision: 0.7132 - val_recall: 0.6410 - lr: 0.0010
# Epoch 4/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.8456 - iou_score: 0.1154 - f1-score: 0.8310 - precision: 0.8579 - recall: 0.8119 - val_loss: 0.8537 - val_iou_score: 0.1090 - val_f1-score: 0.8042 - val_precision: 0.8565 - val_recall: 0.7780 - lr: 0.0010
# Epoch 5/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.8368 - iou_score: 0.1238 - f1-score: 0.8497 - precision: 0.8734 - recall: 0.8328 - val_loss: 0.8344 - val_iou_score: 0.1272 - val_f1-score: 0.8510 - val_precision: 0.8785 - val_recall: 0.8297 - lr: 0.0010
# Epoch 6/200
# 90/90 [==============================] - 49s 547ms/step - loss: 0.8349 - iou_score: 0.1257 - f1-score: 0.8566 - precision: 0.8777 - recall: 0.8416 - val_loss: 0.8363 - val_iou_score: 0.1249 - val_f1-score: 0.8502 - val_precision: 0.8672 - val_recall: 0.8368 - lr: 0.0010
# Epoch 7/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.8304 - iou_score: 0.1302 - f1-score: 0.8643 - precision: 0.8816 - recall: 0.8519 - val_loss: 0.8349 - val_iou_score: 0.1275 - val_f1-score: 0.8291 - val_precision: 0.8714 - val_recall: 0.8031 - lr: 0.0010
# Epoch 8/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.
200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7810 - iou_score: 0.1934 - f1-score: 0.9303 - precision: 0.9387 - recall: 0.9232 - val_loss: 0.8061 - val_iou_score: 0.1584 - val_f1-score: 0.9053 - val_precision: 0.9187 - val_recall: 0.8938 - lr: 1.0000e-04
# Epoch 47/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7810 - iou_score: 0.1935 - f1-score: 0.9301 - precision: 0.9386 - recall: 0.9230 - val_loss: 0.8062 - val_iou_score: 0.1582 - val_f1-score: 0.9053 - val_precision: 0.9190 - val_recall: 0.8937 - lr: 1.0000e-04
# Epoch 48/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7806 - iou_score: 0.1939 - f1-score: 0.9304 - precision: 0.9393 - recall: 0.9230 - val_loss: 0.8061 - val_iou_score: 0.1580 - val_f1-score: 0.9048 - val_precision: 0.9143 - val_recall: 0.8970 - lr: 1.0000e-04
# Epoch 49/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7803 - iou_score: 0.1945 - f1-score: 0.9311 - precision: 0.9403 - recall: 0.9233 - val_loss: 0.8065 - val_iou_score: 0.1574 - val_f1-score: 0.9045 - val_precision: 0.9185 - val_recall: 0.8933 - lr: 1.0000e-04
# Epoch 50/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7798 - iou_score: 0.1952 - f1-score: 0.9316 - precision: 0.9404 - recall: 0.9241 - val_loss: 0.8059 - val_iou_score: 0.1586 - val_f1-score: 0.9054 - val_precision: 0.9147 - val_recall: 0.8978 - lr: 1.0000e-04
# Epoch 51/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7799 - iou_score: 0.1949 - f1-score: 0.9313 - precision: 0.9397 - recall: 0.9241 - val_loss: 0.8060 - val_iou_score: 0.1585 - val_f1-score: 0.9056 - val_precision: 0.9170 - val_recall: 0.8962 - lr: 1.0000e-04
# Epoch 52/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7793 - iou_score: 0.1959 - f1-score: 0.9321 - precision: 0.9410 - recall: 0.9244 - val_loss: 0.8060 - val_iou_score: 0.1585 - val_f1-score: 0.9057 - val_precision: 0.9199 - val_recall: 0.8940 - lr: 1.0000e-04
# Epoch 53/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7790 - iou_score: 0.1962 - f1-score: 0.9324 - precision: 0.9411 - recall: 0.9251 - val_loss: 0.8056 - val_iou_score: 0.1590 - val_f1-score: 0.9062 - val_precision: 0.9201 - val_recall: 0.8944 - lr: 1.0000e-04
# Epoch 54/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7790 - iou_score: 0.1965 - f1-score: 0.9327 - precision: 0.9419 - recall: 0.9249 - val_loss: 0.8059 - val_iou_score: 0.1585 - val_f1-score: 0.9058 - val_precision: 0.9214 - val_recall: 0.8927 - lr: 1.0000e-04
# Epoch 55/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7787 - iou_score: 0.1968 - f1-score: 0.9330 - precision: 0.9422 - recall: 0.9252 - val_loss: 0.8060 - val_iou_score: 0.1585 - val_f1-score: 0.9059 - val_precision: 0.9195 - val_recall: 0.8946 - lr: 1.0000e-04
# Epoch 56/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7781 - iou_score: 0.1976 - f1-score: 0.9336 - precision: 0.9424 - recall: 0.9260 - val_loss: 0.8053 - val_iou_score: 0.1592 - val_f1-score: 0.9065 - val_precision: 0.9188 - val_recall: 0.8960 - lr: 1.0000e-04
# Epoch 57/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7781 - iou_score: 0.1977 - f1-score: 0.9337 - precision: 0.9428 - recall: 0.9260 - val_loss: 0.8058 - val_iou_score: 0.1586 - val_f1-score: 0.9061 - val_precision: 0.9193 - val_recall: 0.8952 - lr: 1.0000e-04
# Epoch 58/200
# 90/90 [==============================] - 49s 547ms/step - loss: 0.7779 - iou_score: 0.1983 - f1-score: 0.9339 - precision: 0.9427 - recall: 0.9267 - val_loss: 0.8056 - val_iou_score: 0.1589 - val_f1-score: 0.9064 - val_precision: 0.9202 - val_recall: 0.8948 - lr: 1.0000e-04
# Epoch 59/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7774 - iou_score: 0.1988 - f1-score: 0.9346 - precision: 0.9440 - recall: 0.9266 - val_loss: 0.8057 - val_iou_score: 0.1587 - val_f1-score: 0.9064 - val_precision: 0.9179 - val_recall: 0.8966 - lr: 1.0000e-04
# Epoch 60/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7771 - iou_score: 0.1993 - f1-score: 0.9350 - precision: 0.9440 - recall: 0.9273 - val_loss: 0.8062 - val_iou_score: 0.1582 - val_f1-score: 0.9061 - val_precision: 0.9211 - val_recall: 0.8936 - lr: 1.0000e-04
# Epoch 61/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7770 - iou_score: 0.1995 - f1-score: 0.9350 - precision: 0.9447 - recall: 0.9268 - val_loss: 0.8059 - val_iou_score: 0.1585 - val_f1-score: 0.9062 - val_precision: 0.9193 - val_recall: 0.8954 - lr: 1.0000e-04
# Epoch 62/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7765 - iou_score: 0.2001 - f1-score: 0.9357 - precision: 0.9452 - recall: 0.9275 - val_loss: 0.8064 - val_iou_score: 0.1579 - val_f1-score: 0.9059 - val_precision: 0.9189 - val_recall: 0.8953 - lr: 1.0000e-04
# Epoch 63/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7763 - iou_score: 0.2005 - f1-score: 0.9360 - precision: 0.9448 - recall: 0.9284 - val_loss: 0.8061 - val_iou_score: 0.1583 - val_f1-score: 0.9062 - val_precision: 0.9215 - val_recall: 0.8936 - lr: 1.0000e-04
# Epoch 64/200
# 90/90 [==============================] - 49s 547ms/step - loss: 0.7763 - iou_score: 0.2005 - f1-score: 0.9361 - precision: 0.9451 - recall: 0.9285 - val_loss: 0.8057 - val_iou_score: 0.1589 - val_f1-score: 0.9066 - val_precision: 0.9186 - val_recall: 0.8968 - lr: 1.0000e-04
# Epoch 65/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7760 - iou_score: 0.2011 - f1-score: 0.9364 - precision: 0.9456 - recall: 0.9286 - val_loss: 0.8051 - val_iou_score: 0.1596 - val_f1-score: 0.9071 - val_precision: 0.9189 - val_recall: 0.8974 - lr: 1.0000e-04
# Epoch 66/200
# 90/90 [==============================] - 49s 546ms/step - loss: 0.7761 - iou_score: 0.2008 - f1-score: 0.9363 - precision: 0.9450 - recall: 0.9291 - val_loss: 0.8051 - val_iou_score: 0.1594 - val_f1-score: 0.9071 - val_precision: 0.9208 - val_recall: 0.8957 - lr: 1.0000e-04
# Epoch 67/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7756 - iou_score: 0.2016 - f1-score: 0.9367 - precision: 0.9457 - recall: 0.9292 - val_loss: 0.8050 - val_iou_score: 0.1596 - val_f1-score: 0.9074 - val_precision: 0.9209 - val_recall: 0.8960 - lr: 1.0000e-04
# Epoch 68/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7755 - iou_score: 0.2019 - f1-score: 0.9371 - precision: 0.9465 - recall: 0.9291 - val_loss: 0.8047 - val_iou_score: 0.1600 - val_f1-score: 0.9079 - val_precision: 0.9206 - val_recall: 0.8975 - lr: 1.0000e-04
# Epoch 69/200
# 90/90 [==============================] - 50s 560ms/step - loss: 0.7751 - iou_score: 0.2025 - f1-score: 0.9376 - precision: 0.9465 - recall: 0.9300 - val_loss: 0.8048 - val_iou_score: 0.1599 - val_f1-score: 0.9079 - val_precision: 0.9180 - val_recall: 0.8992 - lr: 1.0000e-04
# Epoch 70/200
# 90/90 [==============================] - 50s 550ms/step - loss: 0.7748 - iou_score: 0.2029 - f1-score: 0.9379 - precision: 0.9471 - recall: 0.9300 - val_loss: 0.8047 - val_iou_score: 0.1601 - val_f1-score: 0.9079 - val_precision: 0.9198 - val_recall: 0.8979 - lr: 1.0000e-04
# Epoch 71/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7749 - iou_score: 0.2028 - f1-score: 0.9380 - precision: 0.9470 - recall: 0.9304 - val_loss: 0.8047 - val_iou_score: 0.1602 - val_f1-score: 0.9080 - val_precision: 0.9233 - val_recall: 0.8952 - lr: 1.0000e-04
# Epoch 72/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7745 - iou_score: 0.2033 - f1-score: 0.9384 - precision: 0.9479 - recall: 0.9302 - val_loss: 0.8052 - val_iou_score: 0.1593 - val_f1-score: 0.9075 - val_precision: 0.9223 - val_recall: 0.8955 - lr: 1.0000e-04
# Epoch 73/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7746 - iou_score: 0.2031 - f1-score: 0.9381 - precision: 0.9473 - recall: 0.9302 - val_loss: 0.8044 - val_iou_score: 0.1604 - val_f1-score: 0.9083 - val_precision: 0.9206 - val_recall: 0.8980 - lr: 1.0000e-04
# Epoch 74/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7741 - iou_score: 0.2039 - f1-score: 0.9388 - precision: 0.9482 - recall: 0.9309 - val_loss: 0.8046 - val_iou_score: 0.1603 - val_f1-score: 0.9079 - val_precision: 0.9192 - val_recall: 0.8988 - lr: 1.0000e-04
# Epoch 75/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7739 - iou_score: 0.2043 - f1-score: 0.9391 - precision: 0.9479 - recall: 0.9318 - val_loss: 0.8043 - val_iou_score: 0.1606 - val_f1-score: 0.9084 - val_precision: 0.9245 - val_recall: 0.8951 - lr: 1.0000e-04
# Epoch 76/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7741 - iou_score: 0.2040 - f1-score: 0.9389 - precision: 0.9485 - recall: 0.9308 - val_loss: 0.8052 - val_iou_score: 0.1593 - val_f1-score: 0.9074 - val_precision: 0.9173 - val_recall: 0.8993 - lr: 1.0000e-04
# Epoch 77/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7736 - iou_score: 0.2048 - f1-score: 0.9396 - precision: 0.9486 - recall: 0.9319 - val_loss: 0.8044 - val_iou_score: 0.1606 - val_f1-score: 0.9085 - val_precision: 0.9233 - val_recall: 0.8961 - lr: 1.0000e-04
# Epoch 78/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7737 - iou_score: 0.2047 - f1-score: 0.9395 - precision: 0.9488 - recall: 0.9314 - val_loss: 0.8048 - val_iou_score: 0.1599 - val_f1-score: 0.9080 - val_precision: 0.9237 - val_recall: 0.8946 - lr: 1.0000e-04
# Epoch 79/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7734 - iou_score: 0.2050 - f1-score: 0.9398 - precision: 0.9488 - recall: 0.9322 - val_loss: 0.8039 - val_iou_score: 0.1610 - val_f1-score: 0.9088 - val_precision: 0.9216 - val_recall: 0.8980 - lr: 1.0000e-04
# Epoch 80/200
# 90/90 [==============================] - 50s 560ms/step - loss: 0.7732 - iou_score: 0.2054 - f1-score: 0.9400 - precision: 0.9493 - recall: 0.9323 - val_loss: 0.8039 - val_iou_score: 0.1610 - val_f1-score: 0.9086 - val_precision: 0.9232 - val_recall: 0.8959 - lr: 1.0000e-04
# Epoch 81/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7732 - iou_score: 0.2054 - f1-score: 0.9402 - precision: 0.9492 - recall: 0.9325 - val_loss: 0.8039 - val_iou_score: 0.1611 - val_f1-score: 0.9088 - val_precision: 0.9245 - val_recall: 0.8954 - lr: 1.0000e-04
# Epoch 82/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7729 - iou_score: 0.2059 - f1-score: 0.9404 - precision: 0.9496 - recall: 0.9327 - val_loss: 0.8046 - val_iou_score: 0.1603 - val_f1-score: 0.9082 - val_precision: 0.9250 - val_recall: 0.8945 - lr: 1.0000e-04
# Epoch 83/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7727 - iou_score: 0.2062 - f1-score: 0.9407 - precision: 0.9504 - recall: 0.9326 - val_loss: 0.8040 - val_iou_score: 0.1609 - val_f1-score: 0.9091 - val_precision: 0.9224 - val_recall: 0.8978 - lr: 1.0000e-04
# Epoch 84/200
# 90/90 [==============================] - 50s 560ms/step - loss: 0.7727 - iou_score: 0.2062 - f1-score: 0.9402 - precision: 0.9489 - recall: 0.9329 - val_loss: 0.8047 - val_iou_score: 0.1598 - val_f1-score: 0.9077 - val_precision: 0.9199 - val_recall: 0.8978 - lr: 1.0000e-04
# Epoch 85/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7726 - iou_score: 0.2064 - f1-score: 0.9408 - precision: 0.9498 - recall: 0.9330 - val_loss: 0.8043 - val_iou_score: 0.1607 - val_f1-score: 0.9085 - val_precision: 0.9232 - val_recall: 0.8963 - lr: 1.0000e-04
# Epoch 86/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7723 - iou_score: 0.2071 - f1-score: 0.9414 - precision: 0.9506 - recall: 0.9336 - val_loss: 0.8041 - val_iou_score: 0.1611 - val_f1-score: 0.9090 - val_precision: 0.9217 - val_recall: 0.8981 - lr: 1.0000e-04
# Epoch 87/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7721 - iou_score: 0.2071 - f1-score: 0.9415 - precision: 0.9504 - recall: 0.9338 - val_loss: 0.8034 - val_iou_score: 0.1618 - val_f1-score: 0.9097 - val_precision: 0.9242 - val_recall: 0.8974 - lr: 1.0000e-04
# Epoch 88/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7717 - iou_score: 0.2077 - f1-score: 0.9418 - precision: 0.9510 - recall: 0.9339 - val_loss: 0.8043 - val_iou_score: 0.1606 - val_f1-score: 0.9088 - val_precision: 0.9233 - val_recall: 0.8964 - lr: 1.0000e-04
# Epoch 89/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7720 - iou_score: 0.2072 - f1-score: 0.9416 - precision: 0.9506 - recall: 0.9339 - val_loss: 0.8038 - val_iou_score: 0.1611 - val_f1-score: 0.9092 - val_precision: 0.9262 - val_recall: 0.8948 - lr: 1.0000e-04
# Epoch 90/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7716 - iou_score: 0.2079 - f1-score: 0.9419 - precision: 0.9509 - recall: 0.9343 - val_loss: 0.8031 - val_iou_score: 0.1620 - val_f1-score: 0.9101 - val_precision: 0.9226 - val_recall: 0.8996 - lr: 1.0000e-04
# Epoch 91/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7712 - iou_score: 0.2085 - f1-score: 0.9424 - precision: 0.9512 - recall: 0.9349 - val_loss: 0.8041 - val_iou_score: 0.1606 - val_f1-score: 0.9089 - val_precision: 0.9213 - val_recall: 0.8983 - lr: 1.0000e-04
# Epoch 92/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7713 - iou_score: 0.2083 - f1-score: 0.9424 - precision: 0.9509 - recall: 0.9352 - val_loss: 0.8036 - val_iou_score: 0.1614 - val_f1-score: 0.9095 - val_precision: 0.9234 - val_recall: 0.8982 - lr: 1.0000e-04
# Epoch 93/200
# 90/90 [==============================] - 49s 547ms/step - loss: 0.7711 - iou_score: 0.2086 - f1-score: 0.9426 - precision: 0.9515 - recall: 0.9350 - val_loss: 0.8037 - val_iou_score: 0.1612 - val_f1-score: 0.9093 - val_precision: 0.9230 - val_recall: 0.8981 - lr: 1.0000e-04
# Epoch 94/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7711 - iou_score: 0.2088 - f1-score: 0.9427 - precision: 0.9518 - recall: 0.9350 - val_loss: 0.8034 - val_iou_score: 0.1618 - val_f1-score: 0.9099 - val_precision: 0.9197 - val_recall: 0.9016 - lr: 1.0000e-04
# Epoch 95/200
# 90/90 [==============================] - 49s 547ms/step - loss: 0.7709 - iou_score: 0.2091 - f1-score: 0.9430 - precision: 0.9517 - recall: 0.9356 - val_loss: 0.8036 - val_iou_score: 0.1614 - val_f1-score: 0.9097 - val_precision: 0.9225 - val_recall: 0.8992 - lr: 1.0000e-04
# Epoch 96/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7707 - iou_score: 0.2094 - f1-score: 0.9433 - precision: 0.9523 - recall: 0.9355 - val_loss: 0.8032 - val_iou_score: 0.1618 - val_f1-score: 0.9099 - val_precision: 0.9192 - val_recall: 0.9024 - lr: 1.0000e-04
# Epoch 97/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7705 - iou_score: 0.2098 - f1-score: 0.9435 - precision: 0.9525 - recall: 0.9359 - val_loss: 0.8029 - val_iou_score: 0.1622 - val_f1-score: 0.9099 - val_precision: 0.9235 - val_recall: 0.8982 - lr: 1.0000e-04
# Epoch 98/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7703 - iou_score: 0.2100 - f1-score: 0.9437 - precision: 0.9524 - recall: 0.9363 - val_loss: 0.8038 - val_iou_score: 0.1612 - val_f1-score: 0.9092 - val_precision: 0.9216 - val_recall: 0.8993 - lr: 1.0000e-04
# Epoch 99/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7702 - iou_score: 0.2101 - f1-score: 0.9438 - precision: 0.9528 - recall: 0.9360 - val_loss: 0.8035 - val_iou_score: 0.1615 - val_f1-score: 0.9097 - val_precision: 0.9249 - val_recall: 0.8972 - lr: 1.0000e-04
# Epoch 100/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7701 - iou_score: 0.2103 - f1-score: 0.9439 - precision: 0.9530 - recall: 0.9362 - val_loss: 0.8036 - val_iou_score: 0.1611 - val_f1-score: 0.9095 - val_precision: 0.9234 - val_recall: 0.8976 - lr: 1.0000e-04
# Epoch 101/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7700 - iou_score: 0.2106 - f1-score: 0.9442 - precision: 0.9525 - recall: 0.9373 - val_loss: 0.8031 - val_iou_score: 0.1619 - val_f1-score: 0.9100 - val_precision: 0.9228 - val_recall: 0.8990 - lr: 1.0000e-04
# Epoch 102/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7701 - iou_score: 0.2103 - f1-score: 0.9441 - precision: 0.9531 - recall: 0.9364 - val_loss: 0.8032 - val_iou_score: 0.1618 - val_f1-score: 0.9101 - val_precision: 0.9221 - val_recall: 0.9000 - lr: 1.0000e-04
# Epoch 103/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7697 - iou_score: 0.2111 - f1-score: 0.9444 - precision: 0.9528 - recall: 0.9373 - val_loss: 0.8028 - val_iou_score: 0.1625 - val_f1-score: 0.9104 - val_precision: 0.9231 - val_recall: 0.9000 - lr: 1.0000e-04
# Epoch 104/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7696 - iou_score: 0.2111 - f1-score: 0.9447 - precision: 0.9538 - recall: 0.9369 - val_loss: 0.8038 - val_iou_score: 0.1611 - val_f1-score: 0.9095 - val_precision: 0.9209 - val_recall: 0.9004 - lr: 1.0000e-04
# Epoch 105/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7694 - iou_score: 0.2116 - f1-score: 0.9450 - precision: 0.9537 - recall: 0.9376 - val_loss: 0.8037 - val_iou_score: 0.1613 - val_f1-score: 0.9098 - val_precision: 0.9255 - val_recall: 0.8971 - lr: 1.0000e-04
# Epoch 106/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7694 - iou_score: 0.2113 - f1-score: 0.9448 - precision: 0.9537 - recall: 0.9372 - val_loss: 0.8032 - val_iou_score: 0.1618 - val_f1-score: 0.9101 - val_precision: 0.9226 - val_recall: 0.8995 - lr: 1.0000e-04
# Epoch 107/200
# 90/90 [==============================] - 50s 559ms/step - loss: 0.7695 - iou_score: 0.2115 - f1-score: 0.9449 - precision: 0.9537 - recall: 0.9375 - val_loss: 0.8034 - val_iou_score: 0.1617 - val_f1-score: 0.9099 - val_precision: 0.9242 - val_recall: 0.8981 - lr: 1.0000e-04
# Epoch 108/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7694 - iou_score: 0.2115 - f1-score: 0.9450 - precision: 0.9538 - recall: 0.9375 - val_loss: 0.8034 - val_iou_score: 0.1617 - val_f1-score: 0.9098 - val_precision: 0.9279 - val_recall: 0.8944 - lr: 1.0000e-04
# Epoch 109/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7690 - iou_score: 0.2121 - f1-score: 0.9452 - precision: 0.9539 - recall: 0.9378 - val_loss: 0.8033 - val_iou_score: 0.1618 - val_f1-score: 0.9101 - val_precision: 0.9242 - val_recall: 0.8982 - lr: 1.0000e-04
# Epoch 110/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7689 - iou_score: 0.2121 - f1-score: 0.9456 - precision: 0.9548 - recall: 0.9376 - val_loss: 0.8034 - val_iou_score: 0.1616 - val_f1-score: 0.9101 - val_precision: 0.9233 - val_recall: 0.8992 - lr: 1.0000e-04
# Epoch 111/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7688 - iou_score: 0.2124 - f1-score: 0.9457 - precision: 0.9540 - recall: 0.9387 - val_loss: 0.8029 - val_iou_score: 0.1625 - val_f1-score: 0.9108 - val_precision: 0.9244 - val_recall: 0.8991 - lr: 1.0000e-04
# Epoch 112/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7688 - iou_score: 0.2123 - f1-score: 0.9459 - precision: 0.9547 - recall: 0.9382 - val_loss: 0.8030 - val_iou_score: 0.1623 - val_f1-score: 0.9107 - val_precision: 0.9238 - val_recall: 0.8995 - lr: 1.0000e-04
# Epoch 113/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7688 - iou_score: 0.2124 - f1-score: 0.9457 - precision: 0.9544 - recall: 0.9383 - val_loss: 0.8028 - val_iou_score: 0.1623 - val_f1-score: 0.9103 - val_precision: 0.9236 - val_recall: 0.8989 - lr: 1.0000e-04
# Epoch 114/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7685 - iou_score: 0.2131 - f1-score: 0.9460 - precision: 0.9553 - recall: 0.9381 - val_loss: 0.8024 - val_iou_score: 0.1629 - val_f1-score: 0.9110 - val_precision: 0.9238 - val_recall: 0.9001 - lr: 1.0000e-05
# Epoch 115/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7678 - iou_score: 0.2142 - f1-score: 0.9469 - precision: 0.9557 - recall: 0.9395 - val_loss: 0.8025 - val_iou_score: 0.1628 - val_f1-score: 0.9109 - val_precision: 0.9236 - val_recall: 0.9002 - lr: 1.0000e-05
# Epoch 116/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7678 - iou_score: 0.2141 - f1-score: 0.9469 - precision: 0.9557 - recall: 0.9394 - val_loss: 0.8024 - val_iou_score: 0.1630 - val_f1-score: 0.9111 - val_precision: 0.9242 - val_recall: 0.9002 - lr: 1.0000e-05
# Epoch 117/200
# 90/90 [==============================] - 49s 547ms/step - loss: 0.7675 - iou_score: 0.2146 - f1-score: 0.9473 - precision: 0.9560 - recall: 0.9398 - val_loss: 0.8024 - val_iou_score: 0.1628 - val_f1-score: 0.9110 - val_precision: 0.9245 - val_recall: 0.8998 - lr: 1.0000e-05
# Epoch 118/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7674 - iou_score: 0.2149 - f1-score: 0.9473 - precision: 0.9563 - recall: 0.9395 - val_loss: 0.8023 - val_iou_score: 0.1631 - val_f1-score: 0.9112 - val_precision: 0.9246 - val_recall: 0.9000 - lr: 1.0000e-05
# Epoch 119/200
# 90/90 [==============================] - 50s 550ms/step - loss: 0.7674 - iou_score: 0.2149 - f1-score: 0.9474 - precision: 0.9566 - recall: 0.9396 - val_loss: 0.8022 - val_iou_score: 0.1633 - val_f1-score: 0.9115 - val_precision: 0.9244 - val_recall: 0.9006 - lr: 1.0000e-05
# Epoch 120/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7672 - iou_score: 0.2152 - f1-score: 0.9478 - precision: 0.9566 - recall: 0.9401 - val_loss: 0.8024 - val_iou_score: 0.1630 - val_f1-score: 0.9112 - val_precision: 0.9245 - val_recall: 0.9000 - lr: 1.0000e-05
# Epoch 121/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7672 - iou_score: 0.2153 - f1-score: 0.9478 - precision: 0.9569 - recall: 0.9399 - val_loss: 0.8023 - val_iou_score: 0.1632 - val_f1-score: 0.9114 - val_precision: 0.9239 - val_recall: 0.9009 - lr: 1.0000e-05
# Epoch 122/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7671 - iou_score: 0.2152 - f1-score: 0.9477 - precision: 0.9568 - recall: 0.9399 - val_loss: 0.8024 - val_iou_score: 0.1629 - val_f1-score: 0.9111 - val_precision: 0.9240 - val_recall: 0.9003 - lr: 1.0000e-05
# Epoch 123/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7671 - iou_score: 0.2154 - f1-score: 0.9478 - precision: 0.9568 - recall: 0.9401 - val_loss: 0.8023 - val_iou_score: 0.1630 - val_f1-score: 0.9112 - val_precision: 0.9246 - val_recall: 0.9000 - lr: 1.0000e-05
# Epoch 124/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7672 - iou_score: 0.2152 - f1-score: 0.9477 - precision: 0.9566 - recall: 0.9400 - val_loss: 0.8022 - val_iou_score: 0.1632 - val_f1-score: 0.9114 - val_precision: 0.9246 - val_recall: 0.9003 - lr: 1.0000e-05
# Epoch 125/200
# 90/90 [==============================] - 50s 551ms/step - loss: 0.7672 - iou_score: 0.2151 - f1-score: 0.9476 - precision: 0.9567 - recall: 0.9399 - val_loss: 0.8022 - val_iou_score: 0.1634 - val_f1-score: 0.9115 - val_precision: 0.9238 - val_recall: 0.9011 - lr: 1.0000e-05
# Epoch 126/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7671 - iou_score: 0.2154 - f1-score: 0.9478 - precision: 0.9568 - recall: 0.9401 - val_loss: 0.8023 - val_iou_score: 0.1631 - val_f1-score: 0.9113 - val_precision: 0.9246 - val_recall: 0.9001 - lr: 1.0000e-05
# Epoch 127/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7672 - iou_score: 0.2152 - f1-score: 0.9477 - precision: 0.9570 - recall: 0.9396 - val_loss: 0.8024 - val_iou_score: 0.1629 - val_f1-score: 0.9111 - val_precision: 0.9246 - val_recall: 0.8997 - lr: 1.0000e-05
# Epoch 128/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7671 - iou_score: 0.2154 - f1-score: 0.9480 - precision: 0.9573 - recall: 0.9400 - val_loss: 0.8023 - val_iou_score: 0.1632 - val_f1-score: 0.9113 - val_precision: 0.9248 - val_recall: 0.8999 - lr: 1.0000e-05
# Epoch 129/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7669 - iou_score: 0.2157 - f1-score: 0.9481 - precision: 0.9569 - recall: 0.9404 - val_loss: 0.8023 - val_iou_score: 0.1632 - val_f1-score: 0.9114 - val_precision: 0.9245 - val_recall: 0.9004 - lr: 1.0000e-05
# Epoch 130/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7668 - iou_score: 0.2158 - f1-score: 0.9481 - precision: 0.9572 - recall: 0.9402 - val_loss: 0.8023 - val_iou_score: 0.1631 - val_f1-score: 0.9113 - val_precision: 0.9248 - val_recall: 0.8999 - lr: 1.0000e-05
# Epoch 131/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7669 - iou_score: 0.2157 - f1-score: 0.9480 - precision: 0.9572 - recall: 0.9401 - val_loss: 0.8022 - val_iou_score: 0.1632 - val_f1-score: 0.9114 - val_precision: 0.9242 - val_recall: 0.9006 - lr: 1.0000e-05
# Epoch 132/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7670 - iou_score: 0.2156 - f1-score: 0.9479 - precision: 0.9567 - recall: 0.9403 - val_loss: 0.8021 - val_iou_score: 0.1635 - val_f1-score: 0.9115 - val_precision: 0.9243 - val_recall: 0.9008 - lr: 1.0000e-05
# Epoch 133/200
# 90/90 [==============================] - 50s 551ms/step - loss: 0.7667 - iou_score: 0.2160 - f1-score: 0.9483 - precision: 0.9574 - recall: 0.9404 - val_loss: 0.8021 - val_iou_score: 0.1635 - val_f1-score: 0.9116 - val_precision: 0.9238 - val_recall: 0.9014 - lr: 1.0000e-05
# Epoch 134/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7667 - iou_score: 0.2161 - f1-score: 0.9483 - precision: 0.9570 - recall: 0.9408 - val_loss: 0.8022 - val_iou_score: 0.1633 - val_f1-score: 0.9114 - val_precision: 0.9249 - val_recall: 0.9002 - lr: 1.0000e-05
# Epoch 135/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7666 - iou_score: 0.2162 - f1-score: 0.9484 - precision: 0.9576 - recall: 0.9405 - val_loss: 0.8022 - val_iou_score: 0.1632 - val_f1-score: 0.9113 - val_precision: 0.9243 - val_recall: 0.9004 - lr: 1.0000e-05
# Epoch 136/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7667 - iou_score: 0.2160 - f1-score: 0.9482 - precision: 0.9570 - recall: 0.9407 - val_loss: 0.8021 - val_iou_score: 0.1635 - val_f1-score: 0.9116 - val_precision: 0.9241 - val_recall: 0.9010 - lr: 1.0000e-05
# Epoch 137/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7667 - iou_score: 0.2160 - f1-score: 0.9483 - precision: 0.9571 - recall: 0.9406 - val_loss: 0.8022 - val_iou_score: 0.1633 - val_f1-score: 0.9114 - val_precision: 0.9245 - val_recall: 0.9004 - lr: 1.0000e-05
# Epoch 138/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7667 - iou_score: 0.2160 - f1-score: 0.9483 - precision: 0.9575 - recall: 0.9403 - val_loss: 0.8023 - val_iou_score: 0.1632 - val_f1-score: 0.9113 - val_precision: 0.9247 - val_recall: 0.9001 - lr: 1.0000e-05
# Epoch 139/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7666 - iou_score: 0.2162 - f1-score: 0.9484 - precision: 0.9573 - recall: 0.9408 - val_loss: 0.8023 - val_iou_score: 0.1632 - val_f1-score: 0.9114 - val_precision: 0.9246 - val_recall: 0.9003 - lr: 1.0000e-05
# Epoch 140/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7666 - iou_score: 0.2160 - f1-score: 0.9483 - precision: 0.9575 - recall: 0.9404 - val_loss: 0.8024 - val_iou_score: 0.1630 - val_f1-score: 0.9112 - val_precision: 0.9248 - val_recall: 0.8997 - lr: 1.0000e-05
# Epoch 141/200
# 90/90 [==============================] - 49s 550ms/step - loss: 0.7666 - iou_score: 0.2162 - f1-score: 0.9484 - precision: 0.9574 - recall: 0.9407 - val_loss: 0.8022 - val_iou_score: 0.1634 - val_f1-score: 0.9115 - val_precision: 0.9244 - val_recall: 0.9006 - lr: 1.0000e-05
# Epoch 142/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7668 - iou_score: 0.2159 - f1-score: 0.9482 - precision: 0.9576 - recall: 0.9400 - val_loss: 0.8022 - val_iou_score: 0.1631 - val_f1-score: 0.9113 - val_precision: 0.9249 - val_recall: 0.9000 - lr: 1.0000e-05
# Epoch 143/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7667 - iou_score: 0.2161 - f1-score: 0.9485 - precision: 0.9575 - recall: 0.9406 - val_loss: 0.8022 - val_iou_score: 0.1634 - val_f1-score: 0.9115 - val_precision: 0.9249 - val_recall: 0.9004 - lr: 1.0000e-05
# Epoch 144/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7665 - iou_score: 0.2163 - f1-score: 0.9484 - precision: 0.9574 - recall: 0.9407 - val_loss: 0.8022 - val_iou_score: 0.1634 - val_f1-score: 0.9115 - val_precision: 0.9248 - val_recall: 0.9004 - lr: 1.0000e-05
# Epoch 145/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7666 - iou_score: 0.2161 - f1-score: 0.9483 - precision: 0.9574 - recall: 0.9405 - val_loss: 0.8024 - val_iou_score: 0.1631 - val_f1-score: 0.9113 - val_precision: 0.9253 - val_recall: 0.8996 - lr: 1.0000e-05
# Epoch 146/200
# 90/90 [==============================] - 49s 548ms/step - loss: 0.7665 - iou_score: 0.2161 - f1-score: 0.9484 - precision: 0.9575 - recall: 0.9405 - val_loss: 0.8022 - val_iou_score: 0.1632 - val_f1-score: 0.9115 - val_precision: 0.9250 - val_recall: 0.9002 - lr: 1.0000e-05
# Epoch 147/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7664 - iou_score: 0.2164 - f1-score: 0.9486 - precision: 0.9579 - recall: 0.9406 - val_loss: 0.8021 - val_iou_score: 0.1633 - val_f1-score: 0.9115 - val_precision: 0.9249 - val_recall: 0.9002 - lr: 1.0000e-05
# Epoch 148/200
# 90/90 [==============================] - 49s 549ms/step - loss: 0.7664 - iou_score: 0.2165 - f1-score: 0.9486 - precision: 0.9575 - recall: 0.9410 - val_loss: 0.8022 - val_iou_score: 0.1634 - val_f1-score: 0.9115 - val_precision: 0.9248 - val_recall: 0.9005 - lr: 1.0000e-05

# %%
model_in_mem.save('unet_softmax_1500_resnet34.hdf5')
from google.colab import files
files.download('unet_softmax_1500_resnet34.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
# model = load_model('psp_softmax_1500_resnet50.hdf5', compile=False)
model = model_in_mem

# IoU
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 1s 291ms/step
# Mean IoU = 0.8501781
# [[1.6147796e+07 3.6333000e+04 1.3353600e+05 2.2000000e+01]
#  [2.8307000e+04 4.7323400e+05 1.4011000e+04 1.7400000e+03]
#  [1.2181600e+05 1.3856000e+04 6.6084030e+06 3.1000000e+02]
#  [1.6000000e+02 2.8750000e+03 6.6400000e+02 9.8970000e+03]]
# IoU for class1 is:  0.9805578
# IoU for class2 is:  0.82971686
# IoU for class3 is:  0.95876837
# IoU for class4 is:  0.63166964

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, vmin=0, vmax=3, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
