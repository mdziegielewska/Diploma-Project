# %% [markdown]
# ## Semantic segmentation tests

# %%
# read data from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# install segmentation models package
# !pip install -U segmentation-models
# Out:
# Requirement already satisfied: segmentation-models in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)

# %%
import os
import tensorflow as tf
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import normalize
from keras.metrics import MeanIoU
from natsort import natsorted
import tqdm

from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
print(tf.config.list_physical_devices('GPU'))
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# directory = "/media/madziegielewska/Seagate Expansion Drive/MAGISTERKA/diploma-project/Semantic-Segmentation/train_test_data"
directory = "/content/drive/MyDrive/train_test_data"

# %%
# resize images
size_x = 384
size_y = 384

# number of classes for segmentation: background, needle, oocyte and spermatozoid
n_classes = 4

# %%
train_list = glob.glob(f"{directory}/raw/*.*")
train_list_sorted = natsorted(train_list,reverse=False)

mask_list = glob.glob(f"{directory}/vis/*.*")
mask_list_sorted = natsorted(mask_list,reverse=False)

# %%
# capture training image info as a list
train_images = []

for train_path in train_list_sorted:
  img = cv2.imread(train_path, 1)
  img = cv2.resize(img, (size_x, size_y))
  train_images.append(img)

# convert list to array for machine learning processing
train_images = np.array(train_images)
# print(len(train_images))

# %%
# capture mask/label info as a list
train_masks = []

for mask_path in mask_list_sorted:
  mask = cv2.imread(mask_path, 0)
  mask = cv2.resize(mask, (size_x, size_y), interpolation = cv2.INTER_NEAREST)  # otherwise ground truth changes due to interpolation
  train_masks.append(mask)

# convert list to array for machine learning processing
train_masks = np.array(train_masks)
#print(len(train_masks))

# %% [markdown]
# ### Data augmentation

# %%
# function to augment data

def augment_data(images, masks):
    augmented_images = []
    augmented_masks = []

    # iterate over list of images and masks
    for x, y in zip(images, masks):
        augmented_images.append(x)
        augmented_masks.append(y)

        aug = CenterCrop(size_x, size_y, p=1.0)
        augmented = aug(image=x, mask=y)
        x1 = augmented['image']
        y1 = augmented['mask']

        augmented_images.append(x1)
        augmented_masks.append(y1)

        aug = RandomRotate90(p=1.0)
        augmented = aug(image=x, mask=y)
        x2 = augmented['image']
        y2 = augmented['mask']

        augmented_images.append(x2)
        augmented_masks.append(y2)

        aug =GridDistortion(p=1.0)
        augmented = aug(image=x, mask=y)
        x3 = augmented['image']
        y3 = augmented['mask']

        augmented_images.append(x3)
        augmented_masks.append(y3)

        aug = HorizontalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x4 = augmented['image']
        y4 = augmented['mask']

        augmented_images.append(x4)
        augmented_masks.append(y4)

        aug = VerticalFlip(p=1.0)
        augmented = aug(image=x, mask=y)
        x5 = augmented['image']
        y5 = augmented['mask']

        augmented_images.append(x5)
        augmented_masks.append(y5)

    return augmented_images, augmented_masks

# %%
augmented_images, augmented_masks = augment_data(train_images, train_masks)

train_images = augmented_images
train_images = np.array(train_images)

train_masks = augmented_masks
train_masks = np.array(train_masks)

# %%
#encode labels but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = train_masks.shape

train_masks_reshaped = train_masks.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# print("unique train masks: ", np.unique(train_masks))
# print("unique train masks after encoding: ", np.unique(train_masks_encoded_original_shape))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)
train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_images, train_masks_input, test_size = 0.1, random_state = 42)

# %%
b_test = 0
n_test = 0
o_test = 0
s_test = 0

for y in y_test:
  b_test += y.size - np.count_nonzero(y)
  n_test += np.count_nonzero(y == 1)
  o_test += np.count_nonzero(y == 2)
  s_test += np.count_nonzero(y == 3)

# %%
classes_count_mean = [0,0,0,0]

classes_count_mean[0] = b_test/len(y_test)
classes_count_mean[1] = n_test/len(y_test)
classes_count_mean[2] = o_test/len(y_test)
classes_count_mean[3] = s_test/len(y_test)

classes_count_mean = [1/x for x in classes_count_mean]

classess_weights = classes_count_mean / np.linalg.norm(classes_count_mean)

# %%
# print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled

from keras.utils import to_categorical
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))


test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
n_classes=4
activation='softmax'

LR = 0.001
optim = tf.keras.optimizers.legacy.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.array(classess_weights))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(class_weights=classess_weights, threshold=0.5),
           sm.metrics.FScore(threshold=0.5),
           sm.metrics.Precision(threshold=0.5),
           sm.metrics.Recall(threshold=0.5)]

# %% [markdown]
# ### Training

# %%
BACKBONE = 'vgg16'
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# preprocess input
X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# define model
# model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)
model = sm.PSPNet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation=activation)

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics=metrics)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=10)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode="min", factor=0.1,
                              patience=10, min_lr=0.00001)
#print(model.summary())


history=model.fit(X_train,
        y_train_cat,
        batch_size=8,
        epochs=100,
        verbose=1,
        callbacks=[callback, reduce_lr],
        validation_data=(X_test, y_test_cat))


model_in_mem = model
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/100
# 180/180 [==============================] - 100s 436ms/step - loss: 0.9809 - iou_score: 0.0198 - f1-score: 0.5203 - precision: 0.7453 - recall: 0.5046 - val_loss: 1.0113 - val_iou_score: 9.5309e-04 - val_f1-score: 0.4588 - val_precision: 0.8976 - val_recall: 0.4541 - lr: 0.0010
# Epoch 2/100
# 180/180 [==============================] - 74s 413ms/step - loss: 0.9281 - iou_score: 0.0520 - f1-score: 0.6229 - precision: 0.6930 - recall: 0.6118 - val_loss: 0.9727 - val_iou_score: 0.0249 - val_f1-score: 0.4209 - val_precision: 0.5287 - val_recall: 0.5516 - lr: 0.0010
# Epoch 3/100
# 180/180 [==============================] - 74s 410ms/step - loss: 0.8923 - iou_score: 0.0777 - f1-score: 0.6934 - precision: 0.7538 - recall: 0.6750 - val_loss: 0.9093 - val_iou_score: 0.0650 - val_f1-score: 0.5919 - val_precision: 0.8484 - val_recall: 0.5525 - lr: 0.0010
# Epoch 4/100
# 180/180 [==============================] - 74s 410ms/step - loss: 0.8758 - iou_score: 0.0914 - f1-score: 0.7280 - precision: 0.7718 - recall: 0.7174 - val_loss: 0.8761 - val_iou_score: 0.0898 - val_f1-score: 0.6867 - val_precision: 0.8596 - val_recall: 0.6089 - lr: 0.0010
# Epoch 5/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8632 - iou_score: 0.1014 - f1-score: 0.7552 - precision: 0.7956 - recall: 0.7388 - val_loss: 0.8801 - val_iou_score: 0.0893 - val_f1-score: 0.6309 - val_precision: 0.8013 - val_recall: 0.5725 - lr: 0.0010
# Epoch 6/100
# 180/180 [==============================] - 74s 410ms/step - loss: 0.8595 - iou_score: 0.1042 - f1-score: 0.7762 - precision: 0.8086 - recall: 0.7593 - val_loss: 0.8574 - val_iou_score: 0.1076 - val_f1-score: 0.7247 - val_precision: 0.8396 - val_recall: 0.6650 - lr: 0.0010
# Epoch 7/100
# 180/180 [==============================] - 74s 411ms/step - loss: 0.8544 - iou_score: 0.1091 - f1-score: 0.7830 - precision: 0.8141 - recall: 0.7666 - val_loss: 0.8549 - val_iou_score: 0.1100 - val_f1-score: 0.7344 - val_precision: 0.8161 - val_recall: 0.7007 - lr: 0.0010
# Epoch 8/100
# 180/180 [==============================] - 74s 410ms/step - loss: 0.8492 - iou_score: 0.1139 - f1-score: 0.8016 - precision: 0.8282 - recall: 0.7871 - val_loss: 0.8524 - val_iou_score: 0.1110 - val_f1-score: 0.7830 - val_precision: 0.8254 - val_recall: 0.7536 - lr: 0.0010
# Epoch 9/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8463 - iou_score: 0.1165 - f1-score: 0.8077 - precision: 0.8343 - recall: 0.7924 - val_loss: 0.8505 - val_iou_score: 0.1113 - val_f1-score: 0.8004 - val_precision: 0.8391 - val_recall: 0.7745 - lr: 0.0010
# Epoch 10/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8471 - iou_score: 0.1157 - f1-score: 0.8057 - precision: 0.8296 - recall: 0.7927 - val_loss: 0.8609 - val_iou_score: 0.1044 - val_f1-score: 0.7601 - val_precision: 0.7381 - val_recall: 0.7994 - lr: 0.0010
# Epoch 11/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8418 - iou_score: 0.1216 - f1-score: 0.8182 - precision: 0.8419 - recall: 0.8050 - val_loss: 0.8553 - val_iou_score: 0.1189 - val_f1-score: 0.6506 - val_precision: 0.8003 - val_recall: 0.6509 - lr: 0.0010
# Epoch 12/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8377 - iou_score: 0.1252 - f1-score: 0.8251 - precision: 0.8460 - recall: 0.8132 - val_loss: 0.8427 - val_iou_score: 0.1196 - val_f1-score: 0.8181 - val_precision: 0.8221 - val_recall: 0.8217 - lr: 0.0010
# Epoch 13/100
# 180/180 [==============================] - 74s 410ms/step - loss: 0.8354 - iou_score: 0.1271 - f1-score: 0.8335 - precision: 0.8572 - recall: 0.8179 - val_loss: 0.8395 - val_iou_score: 0.1223 - val_f1-score: 0.8297 - val_precision: 0.8432 - val_recall: 0.8214 - lr: 0.0010
# Epoch 14/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8349 - iou_score: 0.1277 - f1-score: 0.8311 - precision: 0.8540 - recall: 0.8168 - val_loss: 0.8460 - val_iou_score: 0.1184 - val_f1-score: 0.7771 - val_precision: 0.8672 - val_recall: 0.7264 - lr: 0.0010
# Epoch 15/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8342 - iou_score: 0.1289 - f1-score: 0.8338 - precision: 0.8580 - recall: 0.8187 - val_loss: 0.8415 - val_iou_score: 0.1195 - val_f1-score: 0.8299 - val_precision: 0.8795 - val_recall: 0.7943 - lr: 0.0010
# Epoch 16/100
# 180/180 [==============================] - 74s 410ms/step - loss: 0.8331 - iou_score: 0.1301 - f1-score: 0.8356 - precision: 0.8590 - recall: 0.8210 - val_loss: 0.8365 - val_iou_score: 0.1248 - val_f1-score: 0.8395 - val_precision: 0.8833 - val_recall: 0.8067 - lr: 0.0010
# Epoch 17/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8318 - iou_score: 0.1311 - f1-score: 0.8391 - precision: 0.8623 - recall: 0.8238 - val_loss: 0.8482 - val_iou_score: 0.1168 - val_f1-score: 0.7898 - val_precision: 0.8072 - val_recall: 0.7901 - lr: 0.0010
# Epoch 18/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8349 - iou_score: 0.1282 - f1-score: 0.8296 - precision: 0.8527 - recall: 0.8157 - val_loss: 0.8452 - val_iou_score: 0.1200 - val_f1-score: 0.7690 - val_precision: 0.8376 - val_recall: 0.7375 - lr: 0.0010
# Epoch 19/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8324 - iou_score: 0.1310 - f1-score: 0.8336 - precision: 0.8565 - recall: 0.8194 - val_loss: 0.8423 - val_iou_score: 0.1244 - val_f1-score: 0.7813 - val_precision: 0.8654 - val_recall: 0.7403 - lr: 0.0010
# Epoch 20/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8264 - iou_score: 0.1372 - f1-score: 0.8464 - precision: 0.8663 - recall: 0.8333 - val_loss: 0.8362 - val_iou_score: 0.1269 - val_f1-score: 0.8119 - val_precision: 0.8807 - val_recall: 0.7653 - lr: 0.0010
# Epoch 21/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8229 - iou_score: 0.1412 - f1-score: 0.8531 - precision: 0.8751 - recall: 0.8376 - val_loss: 0.8382 - val_iou_score: 0.1247 - val_f1-score: 0.8351 - val_precision: 0.8735 - val_recall: 0.8147 - lr: 0.0010
# Epoch 22/100
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8232 - iou_score: 0.1407 - f1-score: 0.8530 - precision: 0.8732 - recall: 0.8389 - val_loss: 0.8346 - val_iou_score: 0.1267 - val_f1-score: 0.8405 - val_precision: 0.8940 - val_recall: 0.8041 - lr: 0.0010
# Epoch 23/100
# 180/180 [==============================] - 73s 408ms/step - loss: 0.8223 - iou_score: 0.1415 - f1-score: 0.8544 - precision: 0.8749 - recall: 0.8400 - val_loss: 0.8350 - val_iou_score: 0.1275 - val_f1-score: 0.8226 - val_precision: 0.8553 - val_recall: 0.8038 - lr: 0.0010
# Epoch 24/100
# 180/180 [==============================] - 73s 408ms/step - loss: 0.8200 - iou_score: 0.1443 - f1-score: 0.8610 - precision: 0.8809 - recall: 0.8470 - val_loss: 0.8377 - val_iou_score: 0.1271 - val_f1-score: 0.8219 - val_precision: 0.8155 - val_recall: 0.8413 - lr: 0.0010
# Epoch 25/100
# 180/180 [==============================] - 73s 408ms/step - loss: 0.8191 - iou_score: 0.1451 - f1-score: 0.8633 - precision: 0.8834 - recall: 0.8495 - val_loss: 0.8264 - val_iou_score: 0.1360 - val_f1-score: 0.8589 - val_precision: 0.8745 - val_recall: 0.8480 - lr: 0.0010
# Epoch 26/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8174 - iou_score: 0.1472 - f1-score: 0.8656 - precision: 0.8829 - recall: 0.8534 - val_loss: 0.8307 - val_iou_score: 0.1309 - val_f1-score: 0.8514 - val_precision: 0.8685 - val_recall: 0.8409 - lr: 0.0010
# Epoch 27/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8165 - iou_score: 0.1483 - f1-score: 0.8672 - precision: 0.8875 - recall: 0.8525 - val_loss: 0.8276 - val_iou_score: 0.1346 - val_f1-score: 0.8578 - val_precision: 0.8759 - val_recall: 0.8449 - lr: 0.0010
# Epoch 28/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8165 - iou_score: 0.1484 - f1-score: 0.8674 - precision: 0.8861 - recall: 0.8540 - val_loss: 0.8282 - val_iou_score: 0.1337 - val_f1-score: 0.8570 - val_precision: 0.8871 - val_recall: 0.8348 - lr: 0.0010
# Epoch 29/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8144 - iou_score: 0.1508 - f1-score: 0.8720 - precision: 0.8896 - recall: 0.8594 - val_loss: 0.8296 - val_iou_score: 0.1328 - val_f1-score: 0.8376 - val_precision: 0.8343 - val_recall: 0.8580 - lr: 0.0010
# Epoch 30/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8155 - iou_score: 0.1495 - f1-score: 0.8699 - precision: 0.8888 - recall: 0.8571 - val_loss: 0.8321 - val_iou_score: 0.1300 - val_f1-score: 0.8496 - val_precision: 0.8665 - val_recall: 0.8446 - lr: 0.0010
# Epoch 31/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8133 - iou_score: 0.1520 - f1-score: 0.8725 - precision: 0.8915 - recall: 0.8582 - val_loss: 0.8255 - val_iou_score: 0.1372 - val_f1-score: 0.8614 - val_precision: 0.8770 - val_recall: 0.8526 - lr: 0.0010
# Epoch 32/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8125 - iou_score: 0.1530 - f1-score: 0.8748 - precision: 0.8926 - recall: 0.8617 - val_loss: 0.8301 - val_iou_score: 0.1314 - val_f1-score: 0.8573 - val_precision: 0.8609 - val_recall: 0.8573 - lr: 0.0010
# Epoch 33/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8154 - iou_score: 0.1498 - f1-score: 0.8664 - precision: 0.8853 - recall: 0.8527 - val_loss: 0.8255 - val_iou_score: 0.1376 - val_f1-score: 0.8523 - val_precision: 0.8704 - val_recall: 0.8413 - lr: 0.0010
# Epoch 34/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8156 - iou_score: 0.1495 - f1-score: 0.8666 - precision: 0.8842 - recall: 0.8555 - val_loss: 0.8280 - val_iou_score: 0.1340 - val_f1-score: 0.8641 - val_precision: 0.8959 - val_recall: 0.8447 - lr: 0.0010
# Epoch 35/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8111 - iou_score: 0.1545 - f1-score: 0.8788 - precision: 0.8971 - recall: 0.8654 - val_loss: 0.8270 - val_iou_score: 0.1354 - val_f1-score: 0.8576 - val_precision: 0.8458 - val_recall: 0.8748 - lr: 0.0010
# Epoch 36/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8091 - iou_score: 0.1570 - f1-score: 0.8829 - precision: 0.8992 - recall: 0.8711 - val_loss: 0.8251 - val_iou_score: 0.1374 - val_f1-score: 0.8640 - val_precision: 0.8896 - val_recall: 0.8491 - lr: 0.0010
# Epoch 37/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8085 - iou_score: 0.1577 - f1-score: 0.8837 - precision: 0.9015 - recall: 0.8708 - val_loss: 0.8223 - val_iou_score: 0.1408 - val_f1-score: 0.8671 - val_precision: 0.8799 - val_recall: 0.8614 - lr: 0.0010
# Epoch 38/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8069 - iou_score: 0.1598 - f1-score: 0.8863 - precision: 0.9034 - recall: 0.8734 - val_loss: 0.8242 - val_iou_score: 0.1380 - val_f1-score: 0.8674 - val_precision: 0.8822 - val_recall: 0.8576 - lr: 0.0010
# Epoch 39/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8061 - iou_score: 0.1606 - f1-score: 0.8875 - precision: 0.9044 - recall: 0.8751 - val_loss: 0.8232 - val_iou_score: 0.1393 - val_f1-score: 0.8689 - val_precision: 0.8638 - val_recall: 0.8794 - lr: 0.0010
# Epoch 40/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8071 - iou_score: 0.1595 - f1-score: 0.8860 - precision: 0.9030 - recall: 0.8733 - val_loss: 0.8287 - val_iou_score: 0.1333 - val_f1-score: 0.8578 - val_precision: 0.8850 - val_recall: 0.8440 - lr: 0.0010
# Epoch 41/100
# 180/180 [==============================] - 73s 407ms/step - loss: 0.8072 - iou_score: 0.1595 - f1-score: 0.8859 - precision: 0.9044 - recall: 0.8722 - val_loss: 0.8272 - val_iou_score: 0.1367 - val_f1-score: 0.8519 - val_precision: 0.8755 - val_recall: 0.8395 - lr: 0.0010
# Epoch 42/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8049 - iou_score: 0.1621 - f1-score: 0.8908 - precision: 0.9083 - recall: 0.8778 - val_loss: 0.8199 - val_iou_score: 0.1431 - val_f1-score: 0.8763 - val_precision: 0.8952 - val_recall: 0.8645 - lr: 0.0010
# Epoch 43/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8030 - iou_score: 0.1645 - f1-score: 0.8946 - precision: 0.9117 - recall: 0.8814 - val_loss: 0.8216 - val_iou_score: 0.1407 - val_f1-score: 0.8762 - val_precision: 0.9123 - val_recall: 0.8496 - lr: 0.0010
# Epoch 44/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8025 - iou_score: 0.1652 - f1-score: 0.8954 - precision: 0.9133 - recall: 0.8821 - val_loss: 0.8203 - val_iou_score: 0.1429 - val_f1-score: 0.8642 - val_precision: 0.9035 - val_recall: 0.8375 - lr: 0.0010
# Epoch 45/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8035 - iou_score: 0.1638 - f1-score: 0.8937 - precision: 0.9097 - recall: 0.8818 - val_loss: 0.8233 - val_iou_score: 0.1389 - val_f1-score: 0.8752 - val_precision: 0.9148 - val_recall: 0.8487 - lr: 0.0010
# Epoch 46/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8030 - iou_score: 0.1648 - f1-score: 0.8957 - precision: 0.9123 - recall: 0.8835 - val_loss: 0.8239 - val_iou_score: 0.1384 - val_f1-score: 0.8719 - val_precision: 0.8993 - val_recall: 0.8542 - lr: 0.0010
# Epoch 47/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8043 - iou_score: 0.1629 - f1-score: 0.8907 - precision: 0.9070 - recall: 0.8784 - val_loss: 0.8231 - val_iou_score: 0.1402 - val_f1-score: 0.8551 - val_precision: 0.8839 - val_recall: 0.8359 - lr: 0.0010
# Epoch 48/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8056 - iou_score: 0.1614 - f1-score: 0.8884 - precision: 0.9047 - recall: 0.8768 - val_loss: 0.8201 - val_iou_score: 0.1425 - val_f1-score: 0.8767 - val_precision: 0.8933 - val_recall: 0.8659 - lr: 0.0010
# Epoch 49/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8011 - iou_score: 0.1668 - f1-score: 0.8973 - precision: 0.9140 - recall: 0.8847 - val_loss: 0.8194 - val_iou_score: 0.1432 - val_f1-score: 0.8794 - val_precision: 0.9072 - val_recall: 0.8595 - lr: 0.0010
# Epoch 50/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8003 - iou_score: 0.1680 - f1-score: 0.9000 - precision: 0.9164 - recall: 0.8872 - val_loss: 0.8199 - val_iou_score: 0.1428 - val_f1-score: 0.8789 - val_precision: 0.9118 - val_recall: 0.8538 - lr: 0.0010
# Epoch 51/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.8005 - iou_score: 0.1679 - f1-score: 0.8985 - precision: 0.9150 - recall: 0.8861 - val_loss: 0.8185 - val_iou_score: 0.1444 - val_f1-score: 0.8814 - val_precision: 0.9034 - val_recall: 0.8674 - lr: 0.0010
# Epoch 52/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7995 - iou_score: 0.1692 - f1-score: 0.9004 - precision: 0.9166 - recall: 0.8887 - val_loss: 0.8198 - val_iou_score: 0.1425 - val_f1-score: 0.8816 - val_precision: 0.9025 - val_recall: 0.8673 - lr: 0.0010
# Epoch 53/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7989 - iou_score: 0.1698 - f1-score: 0.9019 - precision: 0.9182 - recall: 0.8894 - val_loss: 0.8210 - val_iou_score: 0.1414 - val_f1-score: 0.8797 - val_precision: 0.9099 - val_recall: 0.8588 - lr: 0.0010
# Epoch 54/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8006 - iou_score: 0.1675 - f1-score: 0.8977 - precision: 0.9143 - recall: 0.8855 - val_loss: 0.8258 - val_iou_score: 0.1367 - val_f1-score: 0.8664 - val_precision: 0.9138 - val_recall: 0.8350 - lr: 0.0010
# Epoch 55/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7985 - iou_score: 0.1703 - f1-score: 0.9014 - precision: 0.9177 - recall: 0.8889 - val_loss: 0.8264 - val_iou_score: 0.1348 - val_f1-score: 0.8726 - val_precision: 0.9089 - val_recall: 0.8491 - lr: 0.0010
# Epoch 56/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7986 - iou_score: 0.1703 - f1-score: 0.9018 - precision: 0.9174 - recall: 0.8900 - val_loss: 0.8258 - val_iou_score: 0.1366 - val_f1-score: 0.8660 - val_precision: 0.9146 - val_recall: 0.8310 - lr: 0.0010
# Epoch 57/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7979 - iou_score: 0.1713 - f1-score: 0.9030 - precision: 0.9191 - recall: 0.8904 - val_loss: 0.8205 - val_iou_score: 0.1423 - val_f1-score: 0.8771 - val_precision: 0.8917 - val_recall: 0.8724 - lr: 0.0010
# Epoch 58/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7968 - iou_score: 0.1727 - f1-score: 0.9045 - precision: 0.9201 - recall: 0.8927 - val_loss: 0.8196 - val_iou_score: 0.1429 - val_f1-score: 0.8804 - val_precision: 0.9063 - val_recall: 0.8613 - lr: 0.0010
# Epoch 59/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7965 - iou_score: 0.1733 - f1-score: 0.9050 - precision: 0.9198 - recall: 0.8940 - val_loss: 0.8209 - val_iou_score: 0.1416 - val_f1-score: 0.8800 - val_precision: 0.9008 - val_recall: 0.8687 - lr: 0.0010
# Epoch 60/100
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7954 - iou_score: 0.1746 - f1-score: 0.9066 - precision: 0.9219 - recall: 0.8949 - val_loss: 0.8190 - val_iou_score: 0.1436 - val_f1-score: 0.8825 - val_precision: 0.8947 - val_recall: 0.8764 - lr: 0.0010
# Epoch 61/100
# 180/180 [==============================] - 73s 406ms/step - loss: 0.7962 - iou_score: 0.1736 - f1-score: 0.9057 - precision: 0.9211 - recall: 0.8942 - val_loss: 0.8192 - val_iou_score: 0.1433 - val_f1-score: 0.8834 - val_precision: 0.8918 - val_recall: 0.8795 - lr: 0.0010

# %%
model_in_mem.save('psp_softmax_1500_vgg16.hdf5')
from google.colab import files
files.download('psp_softmax_1500_vgg16.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
from sklearn import metrics

# set compile=False as we are not loading it for training, only for prediction.
model = load_model('/content/psp_softmax_1500_vgg16.hdf5', compile=False)
# model = model_in_mem

# IoU
X_test = preprocess_input(X_test)
y_pred2=model.predict(X_test)
y_pred2_argmax=np.argmax(y_pred2, axis=3)

# using built in keras function
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred2_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# to calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)

# verify the prediction on first image
plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
# Out:
# 5/5 [==============================] - 21s 266ms/step
# Mean IoU = 0.8020649
# [[1.6091643e+07 5.1048000e+04 1.1863500e+05 2.9000000e+01]
#  [3.9386000e+04 4.7005700e+05 1.4006000e+04 2.0810000e+03]
#  [3.5934100e+05 2.7274000e+04 6.4051740e+06 2.2900000e+02]
#  [9.8700000e+02 2.6520000e+03 1.5210000e+03 8.8970000e+03]]
# IoU for class1 is:  0.96582294
# IoU for class2 is:  0.77502704
# IoU for class3 is:  0.92477727
# IoU for class4 is:  0.54263234

# %%
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

import torch
import torch.nn as nn
import torch.nn.functional as F

def pixel_accuracy(output, gt):
  with torch.no_grad():
    output = torch.from_numpy(output).float()
    gt = torch.from_numpy(gt).float()

    # apply softmax to the output to get the predicted probabilities for each class
    # then, select the class with the highest probability as the predicted class for each pixel
    output = torch.argmax(F.softmax(output, dim=1), dim=1)
    correct = torch.eq(output, gt).int()

    # compute the accuracy as the number of correctly predicted pixels divided by the total number of pixels
    accuracy = float(correct.sum()) / float(correct.numel())
  return accuracy

# print(pixel_accuracy(test_prediction1, ground_truth))


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0],vmin=0, vmax=3, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, vmin=0, vmax=3, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 1s 822ms/step
